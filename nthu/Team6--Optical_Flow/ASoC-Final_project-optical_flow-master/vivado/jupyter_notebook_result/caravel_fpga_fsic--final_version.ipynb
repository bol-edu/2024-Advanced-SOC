# %%
from __future__ import print_function

import sys
import numpy as np
from time import time
import matplotlib.pyplot as plt 

sys.path.append('/home/xilinx')
from pynq import Overlay
from pynq import allocate
from pynq import MMIO

ROM_SIZE = 0x2000 #8K

SOC_UP = 0x0000;
SOC_LA = 0x1000;
PL_AA_MB = 0x2000;
PL_AA = 0x2100;
SOC_IS = 0x3000;
SOC_AS = 0x4000;
SOC_CC = 0x5000;
PL_AS = 0x6000;
PL_IS = 0x7000;
PL_DMA = 0x8000;
# add userdma base address
PL_UPDMA = 0x9000;

# %%
###ol = Overlay("/home/xilinx/jupyter_notebooks/PS/caravel_fpga.bit")
ol = Overlay("caravel_fpga.bit") # modified
#ol.ip_dict

# %%
ipOUTPIN = ol.output_pin_0
ipPS = ol.caravel_ps_0
# ipReadROMCODE = ol.read_romcode_0

#Add for SPI
ip_QSPI = ol.axi_quad_spi_0

# %%
# ============================================
# AXI QuadSPI Control
# ============================================
XSP_DGIER_OFFSET = 0x1C
XSP_IISR_OFFSET = 0x20
XSP_IIER_OFFSET = 0x28
XSP_SRR_OFFSET = 0x40
XSP_CR_OFFSET = 0x60
XSP_SR_OFFSET = 0x64
XSP_DTR_OFFSET = 0x68
XSP_DRR_OFFSET = 0x6C
XSP_SSR_OFFSET = 0x70
XSP_TFO_OFFSET = 0x74
XSP_RFO_OFFSET = 0x78
XSP_REGISTERS = [0x40, 0x60, 0x64, 0x68, 0x6c, 0x70, 0x74, 0x78, 0x1c, 0x20, 0x28]

XSP_SRR_RESET_MASK = 0x0A
XSP_SR_TX_EMPTY_MASK = 0x04
XSP_SR_TX_FULL_MASK = 0x08
XSP_CR_TRANS_INHIBIT_MASK = 0x100
XSP_CR_LOOPBACK_MASK = 0x01
XSP_CR_ENABLE_MASK = 0x02
XSP_CR_MASTER_MODE_MASK = 0x04
XSP_CR_CLK_POLARITY_MASK = 0x08
XSP_CR_CLK_PHASE_MASK = 0x10
XSP_CR_TXFIFO_RESET_MASK = 0x20
XSP_CR_RXFIFO_RESET_MASK = 0x40
XSP_CR_MANUAL_SS_MASK = 0x80

SLAVE_NO_SELECTION = 0xFFFFFFFF

def cnfg(AxiQspi, clk_phase=0, clk_pol=0):
    print("Configure device")
    # Reset the SPI device
    AxiQspi.write(XSP_SRR_OFFSET, XSP_SRR_RESET_MASK)
    # Enable the transmit empty interrupt, which we use to determine progress on the transmission. 
    AxiQspi.write(XSP_IIER_OFFSET, XSP_SR_TX_EMPTY_MASK)
    # Disable the global IPIF interrupt
    AxiQspi.write(XSP_DGIER_OFFSET, 0)
    # Deselect the slave on the SPI bus
    AxiQspi.write(XSP_SSR_OFFSET, SLAVE_NO_SELECTION)
    # Disable the transmitter, enable Manual Slave Select Assertion, put SPI controller into master mode, and enable it
    ControlReg = AxiQspi.read(XSP_CR_OFFSET)
    ControlReg = ControlReg | XSP_CR_MASTER_MODE_MASK | XSP_CR_MANUAL_SS_MASK | XSP_CR_ENABLE_MASK | XSP_CR_TXFIFO_RESET_MASK | XSP_CR_RXFIFO_RESET_MASK
    AxiQspi.write(XSP_CR_OFFSET, ControlReg)
    ControlReg = AxiQspi.read(XSP_CR_OFFSET)
    ControlReg = ControlReg & ~(XSP_CR_CLK_PHASE_MASK | XSP_CR_CLK_POLARITY_MASK) 
    if clk_phase == 1:
        ControlReg = ControlReg | XSP_CR_CLK_PHASE_MASK
    if clk_pol == 1:
        ControlReg = ControlReg | XSP_CR_CLK_POLARITY_MASK
    AxiQspi.write(XSP_CR_OFFSET, ControlReg)

    return 0

def write_tx_fifo(AxiQspi):
    #print("TransferData")
    ControlReg = AxiQspi.read(XSP_CR_OFFSET)
    ControlReg = ControlReg & ~XSP_CR_TRANS_INHIBIT_MASK
    AxiQspi.write(XSP_CR_OFFSET, ControlReg)

    StatusReg = AxiQspi.read(XSP_SR_OFFSET)
    while (StatusReg & XSP_SR_TX_EMPTY_MASK) == 0:
        StatusReg = AxiQspi.read(XSP_SR_OFFSET)

    #print('XSP_RFO_OFFSET  : 0x{0:08x}'.format(AxiQspi.read(XSP_RFO_OFFSET)))
    ControlReg = AxiQspi.read(XSP_CR_OFFSET)
    ControlReg = ControlReg | XSP_CR_TRANS_INHIBIT_MASK
    AxiQspi.write(XSP_CR_OFFSET, ControlReg)


def read_rx_fifo(bypass_length, AxiQspi):
    #print("ReadResponse")
    resp = list()
    RxFifoStatus = AxiQspi.read(XSP_SR_OFFSET) & 0x01
    
    # By pass the FIFO data during master issue command and address to slave device
    command_addr_length = bypass_length
    counter = 0    
    
    while RxFifoStatus == 0:
        #temp = AxiQspi.read(XSP_RFO_OFFSET)
        #print('XSP_RFO_OFFSET  : 0x{0:08x}'.format(temp))
        temp = AxiQspi.read(XSP_DRR_OFFSET)
        #print('XSP_DRR_OFFSET  : 0x{0:08x}'.format(temp))    

        counter = counter + 1
        if(counter > command_addr_length):
            resp.append(temp)        
        
        RxFifoStatus = AxiQspi.read(XSP_SR_OFFSET) & 0x01

    return resp

# %%
# Check MPRJ_IO input/out/en
# 0x10 : Data signal of ps_mprj_in
#        bit 31~0 - ps_mprj_in[31:0] (Read/Write)
# 0x14 : Data signal of ps_mprj_in
#        bit 5~0 - ps_mprj_in[37:32] (Read/Write)
#        others  - reserved
# 0x1c : Data signal of ps_mprj_out
#        bit 31~0 - ps_mprj_out[31:0] (Read)
# 0x20 : Data signal of ps_mprj_out
#        bit 5~0 - ps_mprj_out[37:32] (Read)
#        others  - reserved
# 0x34 : Data signal of ps_mprj_en
#        bit 31~0 - ps_mprj_en[31:0] (Read)
# 0x38 : Data signal of ps_mprj_en
#        bit 5~0 - ps_mprj_en[37:32] (Read)
#        others  - reserved

print ("0x10 = ", hex(ipPS.read(0x10)))
print ("0x14 = ", hex(ipPS.read(0x14)))
print ("0x1c = ", hex(ipPS.read(0x1c)))
print ("0x20 = ", hex(ipPS.read(0x20)))
print ("0x34 = ", hex(ipPS.read(0x34)))
print ("0x38 = ", hex(ipPS.read(0x38)))
# Out:
# 0x10 =  0x0
# 0x14 =  0x0
# 0x1c =  0x0
# 0x20 =  0x0
# 0x34 =  0xfffffff7
# 0x38 =  0x3f

# %%
# ============================================
# Release Reset First before passthrough mode
# ============================================
# Release Caravel reset
# 0x10 : Data signal of outpin_ctrl
#        bit 0  - outpin_ctrl[0] (Read/Write)
#        others - reserved
print (ipOUTPIN.read(0x10))
ipOUTPIN.write(0x10, 1)
print (ipOUTPIN.read(0x10))
# Out:
# 0
# 1

# %%
# ============================================
# Load firmware (fsic.hex) to memory npROM
# ============================================

# Create np with 8K/4 (4 bytes per index) size and be initiled to 0
npROM = np.zeros(ROM_SIZE >> 2, dtype=np.uint32)

npROM_index = 0
npROM_offset = 0
###fiROM = open("/home/xilinx/jupyter_notebooks/PS/fsic.hex", "r+")
fiROM = open("fsic.hex", "r+") # modified

for line in fiROM:
    # offset header
    if line.startswith('@'):
        # Ignore first char @
        npROM_offset = int(line[1:].strip(b'\x00'.decode()), base = 16)
        npROM_offset = npROM_offset >> 2 # 4byte per offset
        #print (npROM_offset)
        npROM_index = 0
        continue
    #print (line)

    # We suppose the data must be 32bit alignment
    buffer = 0
    bytecount = 0
    for line_byte in line.strip(b'\x00'.decode()).split():
        buffer += int(line_byte, base = 16) << (8 * bytecount)
        bytecount += 1
        # Collect 4 bytes, write to npROM
        if(bytecount == 4):
            npROM[npROM_offset + npROM_index] = buffer
            # Clear buffer and bytecount
            buffer = 0
            bytecount = 0
            npROM_index += 1
            #print (npROM_index)
            continue
    # Fill rest data if not alignment 4 bytes
    if (bytecount != 0):
        npROM[npROM_offset + npROM_index] = buffer
        npROM_index += 1
    
fiROM.close()

# %%
# ============================================
# Enabling passthrou mode
# ============================================
cnfg(ip_QSPI)
# Passthrou mode - Write command
ip_QSPI.write(XSP_DTR_OFFSET, 0xC4) # Pass-Through (management)
ip_QSPI.write(XSP_DTR_OFFSET, 0x02) # Command: Write data to memory
ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Address_byte0
ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Address_byte1
ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Address_byte2

print('XSP_TFO_OFFSET  : 0x{0:08x}'.format(ip_QSPI.read(XSP_TFO_OFFSET)))

ip_QSPI.write(XSP_SSR_OFFSET, 0xFFFFFFFE)
write_tx_fifo(ip_QSPI)

print('XSP_TFO_OFFSET  : 0x{0:08x}'.format(ip_QSPI.read(XSP_TFO_OFFSET)))
# Out:
# Configure device
# XSP_TFO_OFFSET  : 0x00000004
# XSP_TFO_OFFSET  : 0x00000000

# %%
# ============================================
# Writing FW into SPIROM
# ============================================
# Fill up Tx_FIFO (16) for each write_tx_fifo
for index in range (ROM_SIZE >> 2):
     # 4 bytes alignment in npROM
    for byte_shift in range(4):
        tmp = int((npROM[index] >> (byte_shift * 8)) & 0xFF)
        ip_QSPI.write(XSP_DTR_OFFSET, tmp) # Write_data
    # TX_FIFO = 16, 4 * 4 = 16
    if((index % 3) == 3):
        write_tx_fifo(ip_QSPI)
        
# If rest data is not enough 16 bytes. Tx_FIFO is not empty
    StatusReg = ip_QSPI.read(XSP_SR_OFFSET)
    if ((StatusReg & XSP_SR_TX_EMPTY_MASK) == 0):
         write_tx_fifo(ip_QSPI)

# %%
# ============================================
# Read SPIROM for testing
# ============================================
cnfg(ip_QSPI)
# Out:
# Configure device
# 0

# %%
# Test Passthrou mode - Read command
ip_QSPI.write(XSP_DTR_OFFSET, 0xC4) # Pass-Through (management)
ip_QSPI.write(XSP_DTR_OFFSET, 0x03) # Command: Read data from memory
ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Address_byte0
ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Address_byte1
ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Address_byte2
# Write dummy data
data_length = 0x8
for index in range(data_length):
    ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Dummy data

print('XSP_TFO_OFFSET  : 0x{0:08x}'.format(ip_QSPI.read(XSP_TFO_OFFSET)))
ip_QSPI.write(XSP_SSR_OFFSET, 0xFFFFFFFE)
# Out:
# XSP_TFO_OFFSET  : 0x0000000c

# %%
# Issue SPI master cycle
write_tx_fifo(ip_QSPI)

# Read the Rx data
rx_final = read_rx_fifo(5, ip_QSPI)
for data in rx_final:
    print (hex(data))
# Out:
# 0x6f
# 0x0
# 0x0
# 0xb
# 0x13
# 0x0
# 0x0
# 0x0

# %%
# Write dummy data
data_length = 0x8
for index in range(data_length):
    ip_QSPI.write(XSP_DTR_OFFSET, 0x00) # Dummy data

print('XSP_TFO_OFFSET  : 0x{0:08x}'.format(ip_QSPI.read(XSP_TFO_OFFSET)))
# Out:
# XSP_TFO_OFFSET  : 0x00000007

# %%
# Issue SPI master cycle
write_tx_fifo(ip_QSPI)

# Read the Rx data
rx_final = read_rx_fifo(0, ip_QSPI)
for data in rx_final:
    print (hex(data))
# Out:
# 0x13
# 0x0
# 0x0
# 0x0
# 0x13
# 0x0
# 0x0
# 0x0

# %%
# ============================================
# Exit passthrou mode, FW will be fetched
# ============================================
ip_QSPI.write(XSP_SSR_OFFSET, SLAVE_NO_SELECTION)

# %%
# Check MPRJ_IO input/out/en
# 0x10 : Data signal of ps_mprj_in
#        bit 31~0 - ps_mprj_in[31:0] (Read/Write)
# 0x14 : Data signal of ps_mprj_in
#        bit 5~0 - ps_mprj_in[37:32] (Read/Write)
#        others  - reserved
# 0x1c : Data signal of ps_mprj_out
#        bit 31~0 - ps_mprj_out[31:0] (Read)
# 0x20 : Data signal of ps_mprj_out
#        bit 5~0 - ps_mprj_out[37:32] (Read)
#        others  - reserved
# 0x34 : Data signal of ps_mprj_en
#        bit 31~0 - ps_mprj_en[31:0] (Read)
# 0x38 : Data signal of ps_mprj_en
#        bit 5~0 - ps_mprj_en[37:32] (Read)
#        others  - reserved

print ("0x10 = ", hex(ipPS.read(0x10)))
print ("0x14 = ", hex(ipPS.read(0x14)))
print ("0x1c = ", hex(ipPS.read(0x1c)))
print ("0x20 = ", hex(ipPS.read(0x20)))
print ("0x34 = ", hex(ipPS.read(0x34)))
print ("0x38 = ", hex(ipPS.read(0x38)))
# Out:
# 0x10 =  0x0
# 0x14 =  0x0
# 0x1c =  0x0
# 0x20 =  0x0
# 0x34 =  0x3ffff6
# 0x38 =  0x10

# %%
IP_BASE_ADDRESS = 0x60000000
###ADDRESS_RANGE = 0x9000
ADDRESS_RANGE = 0xa000 # modified
mmio = MMIO(IP_BASE_ADDRESS, ADDRESS_RANGE)

# %%
# ====================================================================================== #
# ====================================================================================== #
# PL_FSIC Side Configuration
# ====================================================================================== #
# ====================================================================================== #

# %%
# PL_IS Config
ADDRESS_OFFSET = PL_IS #0x7000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x0

# %%
mmio.write(ADDRESS_OFFSET, 0x12345671)
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x1

# %%
mmio.write(ADDRESS_OFFSET, 0x12345673)
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x3

# %%
# PL_DMA Config
ADDRESS_OFFSET = PL_DMA # 0x8000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))
print("mmio.read(ADDRESS_OFFSET+0x20): ", hex(mmio.read(ADDRESS_OFFSET+0x20)))
print("mmio.read(ADDRESS_OFFSET+0x28): ", hex(mmio.read(ADDRESS_OFFSET+0x28)))
print("mmio.read(ADDRESS_OFFSET+0x30): ", hex(mmio.read(ADDRESS_OFFSET+0x30)))
print("mmio.read(ADDRESS_OFFSET+0x38): ", hex(mmio.read(ADDRESS_OFFSET+0x38)))
print("mmio.read(ADDRESS_OFFSET+0x3C): ", hex(mmio.read(ADDRESS_OFFSET+0x3C)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x4
# mmio.read(ADDRESS_OFFSET+0x10):  0x0
# mmio.read(ADDRESS_OFFSET+0x20):  0x0
# mmio.read(ADDRESS_OFFSET+0x28):  0x0
# mmio.read(ADDRESS_OFFSET+0x30):  0x0
# mmio.read(ADDRESS_OFFSET+0x38):  0x0
# mmio.read(ADDRESS_OFFSET+0x3C):  0x0

# %%
# PL_AS Config
ADDRESS_OFFSET = PL_AS # 0x6000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
mmio.write(ADDRESS_OFFSET, 0x12345676)
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x6
# mmio.read(ADDRESS_OFFSET):  0x6

# %%
# PL_AA Config
ADDRESS_OFFSET = PL_AA # 0x2100
print("mmio.read(ADDRESS_OFFSET+0x00): ", hex(mmio.read(ADDRESS_OFFSET+0x00)))
print("mmio.read(ADDRESS_OFFSET+0x04): ", hex(mmio.read(ADDRESS_OFFSET+0x04)))
# Out:
# mmio.read(ADDRESS_OFFSET+0x00):  0x0
# mmio.read(ADDRESS_OFFSET+0x04):  0x0

# %%
mmio.write(ADDRESS_OFFSET+0x00, 0x11111111)
mmio.write(ADDRESS_OFFSET+0x04, 0x22222222)

# %%
# PL_AA_MB Mailbox
ADDRESS_OFFSET = PL_AA_MB # 0x2000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
print("mmio.read(ADDRESS_OFFSET+0x04): ", hex(mmio.read(ADDRESS_OFFSET+0x04)))
print("mmio.read(ADDRESS_OFFSET+0x08): ", hex(mmio.read(ADDRESS_OFFSET+0x08)))
print("mmio.read(ADDRESS_OFFSET+0x0C): ", hex(mmio.read(ADDRESS_OFFSET+0x0C)))
print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))
print("mmio.read(ADDRESS_OFFSET+0x14): ", hex(mmio.read(ADDRESS_OFFSET+0x14)))
print("mmio.read(ADDRESS_OFFSET+0x18): ", hex(mmio.read(ADDRESS_OFFSET+0x18)))
print("mmio.read(ADDRESS_OFFSET+0x1C): ", hex(mmio.read(ADDRESS_OFFSET+0x1C)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x0
# mmio.read(ADDRESS_OFFSET+0x04):  0x0
# mmio.read(ADDRESS_OFFSET+0x08):  0x0
# mmio.read(ADDRESS_OFFSET+0x0C):  0x0
# mmio.read(ADDRESS_OFFSET+0x10):  0x0
# mmio.read(ADDRESS_OFFSET+0x14):  0x0
# mmio.read(ADDRESS_OFFSET+0x18):  0x0
# mmio.read(ADDRESS_OFFSET+0x1C):  0x0

# %%
mmio.write(ADDRESS_OFFSET, 0x11111112)
mmio.write(ADDRESS_OFFSET+0x04, 0x22222223)
mmio.write(ADDRESS_OFFSET+0x08, 0x33333334)
mmio.write(ADDRESS_OFFSET+0x0C, 0x44444445)
mmio.write(ADDRESS_OFFSET+0x10, 0x55555556)
mmio.write(ADDRESS_OFFSET+0x14, 0x66666667)
mmio.write(ADDRESS_OFFSET+0x18, 0x77777778)
mmio.write(ADDRESS_OFFSET+0x1C, 0x88888889)

# %%
# ====================================================================================== #
# ====================================================================================== #
# PL_Caravel Side Configuration
# ====================================================================================== #
# ====================================================================================== #

# %%
# Caravel-IS Config
ADDRESS_OFFSET = SOC_IS # 0x3000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x3

# %%
# Caravel-IS Config
ADDRESS_OFFSET = 0x3000
mmio.write(ADDRESS_OFFSET, 0x00000003)

# %%
# Caravel-AS Config
ADDRESS_OFFSET = SOC_AS # 0x4000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x6

# %%
# Caravel-AS Config
ADDRESS_OFFSET = SOC_AS # 0x4000
mmio.write(ADDRESS_OFFSET, 0x00000006)

# %%
# Caravel-CC Config
ADDRESS_OFFSET = SOC_CC # 0x5000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x0

# %%
# Caravel-CC Config
ADDRESS_OFFSET = SOC_CC # 0x5000
mmio.write(ADDRESS_OFFSET, 0x00000000)

# %%
# Caravel-LA Config
ADDRESS_OFFSET = SOC_LA # 0x1000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x0

# %%
# Caravel-UP Config
ADDRESS_OFFSET = SOC_UP # 0x0000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET+0x04)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x280

# %%
# ====================================================================================== #
# ====================================================================================== #
# LADMA Verification
# ====================================================================================== #
# ====================================================================================== #

# %%
### # Allocation memory
### ladma_buf = allocate(shape=(1024,), dtype=np.uint32)
### print("ladma_buf.device_address: ", hex(ladma_buf.device_address))
### 
### IP_BASE_ADDRESS = ladma_buf.device_address
### ADDRESS_RANGE = 0x1000
### buf_mmio = MMIO(IP_BASE_ADDRESS, ADDRESS_RANGE)
### # 0x00 : Control signals
### #        bit 0 - ap_start (R/W/COH)
### #        bit 1 - ap_done (R/COR)
### #        bit 2 - ap_idle (R)
### #        bit 3 - ap_ready (R/COR)
### # 0x10 : Buffer transfer done status register
### #        bit 0 - buffer transfer done status (R)
### # 0x20 : Buffer transfer done status clear register
### #        bit 0 - clear buffer transfer done status (R/W)
### # 0x28 : Buffer Length
### #        bit 31~0 - set buffer length (must 1024)
### # 0x30 : Triggered condition 
### #        bit 23~0 - set triggered condidtion (R/W)
### #        others  - reserved
### # 0x34 : Buffer Lower base address 
### #        bit 31~0 - (R/W)
### # 0x38 : Buffer High base address
### #        bit 31~0 - (R/W)
### # ladma Configuration
### ADDRESS_OFFSET = PL_DMA # 0x8000
### # exit clear operation
### mmio.write(ADDRESS_OFFSET + 0x20, 0x00000000)
### # set buffer length
### mmio.write(ADDRESS_OFFSET + 0x28, 0x00000400)
### # set trigger condition
### mmio.write(ADDRESS_OFFSET + 0x30, 0x00000000)
### # set buffer low
### mmio.write(ADDRESS_OFFSET + 0x38, ladma_buf.device_address)
### # set buffer high
### mmio.write(ADDRESS_OFFSET + 0x3C, 0x00000000)

# %%
### ADDRESS_OFFSET = PL_DMA # 0x8000
### print("mmio.read(ADDRESS_OFFSET+0x00): ", hex(mmio.read(ADDRESS_OFFSET+0x00)))
### print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))
### print("mmio.read(ADDRESS_OFFSET+0x20): ", hex(mmio.read(ADDRESS_OFFSET+0x20)))
### print("mmio.read(ADDRESS_OFFSET+0x28): ", hex(mmio.read(ADDRESS_OFFSET+0x28)))
### print("mmio.read(ADDRESS_OFFSET+0x30): ", hex(mmio.read(ADDRESS_OFFSET+0x30)))
### print("mmio.read(ADDRESS_OFFSET+0x38): ", hex(mmio.read(ADDRESS_OFFSET+0x38)))
### print("mmio.read(ADDRESS_OFFSET+0x3C): ", hex(mmio.read(ADDRESS_OFFSET+0x3C)))

# %%
### # ladma Configuration
### ADDRESS_OFFSET = PL_DMA # 0x8000
### # set ap_start
### mmio.write(ADDRESS_OFFSET + 0x00, 0x00000001)

# %%
### # enable la 0xFFFFFF
### ADDRESS_OFFSET = SOC_LA # 0x1000
### mmio.write(ADDRESS_OFFSET, 0x00FFFFFF)
### #print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
### 
### # select target UP
### ADDRESS_OFFSET = SOC_CC # 0x5000
### mmio.write(ADDRESS_OFFSET, 0x00000003)
### #print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))

# %%
### # ladma Configuration
### ADDRESS_OFFSET = PL_DMA # 0x8000
### while True:
###     if mmio.read(ADDRESS_OFFSET+0x10) == 0x01:
###         break
### print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))
### 
### # disable la 0x000000
### ADDRESS_OFFSET = SOC_LA # 0x1000
### mmio.write(ADDRESS_OFFSET, 0x00000000)
### # select fake UP
### ADDRESS_OFFSET = SOC_CC # 0x5000
### mmio.write(ADDRESS_OFFSET, 0x00000000) 
### 
### ADDRESS_OFFSET = PL_DMA # 0x8000
### # clear buffer transfer done operation
### mmio.write(ADDRESS_OFFSET + 0x20, 0x00000001)
### # set ap_start
### mmio.write(ADDRESS_OFFSET + 0x00, 0x00000001)
### while True:
###     if mmio.read(ADDRESS_OFFSET+0x10) != 0x01:
###         break
### print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))

# %%
### ADDRESS_OFFSET = PL_DMA # 0x8000
### print("mmio.read(ADDRESS_OFFSET+0x00): ", hex(mmio.read(ADDRESS_OFFSET+0x00)))
### print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))
### print("mmio.read(ADDRESS_OFFSET+0x20): ", hex(mmio.read(ADDRESS_OFFSET+0x20)))
### print("mmio.read(ADDRESS_OFFSET+0x28): ", hex(mmio.read(ADDRESS_OFFSET+0x28)))
### print("mmio.read(ADDRESS_OFFSET+0x30): ", hex(mmio.read(ADDRESS_OFFSET+0x30)))
### print("mmio.read(ADDRESS_OFFSET+0x38): ", hex(mmio.read(ADDRESS_OFFSET+0x38)))
### print("mmio.read(ADDRESS_OFFSET+0x3C): ", hex(mmio.read(ADDRESS_OFFSET+0x3C)))

# %%
### #dump la log to file
### file = open("simulate.log", "w")
### for i in range(0,0xFFF,4):
###     file.write('{:08x}'.format(buf_mmio.read(i))+"\n")
### file.close()

# %%
### # ladma Configuration
### ADDRESS_OFFSET = PL_DMA # 0x8000
### # exit clear operation
### mmio.write(ADDRESS_OFFSET + 0x20, 0x00000000)
### # set ap_start again
### mmio.write(ADDRESS_OFFSET + 0x00, 0x00000001)
### 
### # Confirming SOC_CC & SOC_LA Reading is still work
### ADDRESS_OFFSET = SOC_CC # 0x5000
### print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
### print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))

# %%
### # Translate simulate.log to output_new.vcd, which can be open by gtakwave
### %run read_la_data.py

# %%
# ====================================================================================== #
# ====================================================================================== #
# OpticalFlow IP + userDMA Verification (Added by us)
# ====================================================================================== #
# ====================================================================================== #

# %%
# Check Caravel-CC Config
ADDRESS_OFFSET = SOC_CC # 0x5000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))
# Out:
# mmio.read(ADDRESS_OFFSET):  0x0

# %%
# Caravel-CC Config
ADDRESS_OFFSET = SOC_CC # 0x5000
# select user project 2
mmio.write(ADDRESS_OFFSET, 0x00000002)

# %%
# Check new Caravel-CC Config
ADDRESS_OFFSET = SOC_CC # 0x5000
print("mmio.read(ADDRESS_OFFSET): ", hex(mmio.read(ADDRESS_OFFSET)))

# The result should be "2" !!!
# Out:
# mmio.read(ADDRESS_OFFSET):  0x2

# %%
# Caravel-UP Config (configure OpticalFlow IP)
ADDRESS_OFFSET = SOC_UP # 0x0000

# %%
# Set rst = 1 (address=0x00)
offset = 0x0
write_data = 0x1
mmio.write(ADDRESS_OFFSET + offset, write_data)

# %%
# Read back & check
read_value = mmio.read(ADDRESS_OFFSET + offset)
if read_value == write_data:
    print("[PASS] Read OpticalFlow address ", hex(ADDRESS_OFFSET + offset), ": read out data = ", hex(read_value), "; golden value = ", hex(write_data))
else:
    print("[ERROR] Read OpticalFlow address ", hex(ADDRESS_OFFSET + offset), ": read out data = ", hex(read_value), "; golden value = ", hex(write_data))
# Out:
# [PASS] Read OpticalFlow address  0x0 : read out data =  0x1 ; golden value =  0x1

# %%
# Set rst = 0 (address=0x00)
offset = 0x0
write_data = 0x0
mmio.write(ADDRESS_OFFSET + offset, write_data)

# %%
# Read back & check
read_value = mmio.read(ADDRESS_OFFSET + offset)
if read_value == write_data:
    print("[PASS] Read OpticalFlow address ", hex(ADDRESS_OFFSET + offset), ": read out data = ", hex(read_value), "; golden value = ", hex(write_data))
else:
    print("[ERROR] Read OpticalFlow address ", hex(ADDRESS_OFFSET + offset), ": read out data = ", hex(read_value), "; golden value = ", hex(write_data))
# Out:
# [PASS] Read OpticalFlow address  0x0 : read out data =  0x0 ; golden value =  0x0

# %%
TST_FRAME_WIDTH = 1024
TST_FRAME_HEIGHT = 436
shift_threshold = 105

# Program widthIn, heightIn, and shift_threshold
mmio.write(ADDRESS_OFFSET + 0x04, TST_FRAME_WIDTH)
mmio.write(ADDRESS_OFFSET + 0x08, TST_FRAME_HEIGHT)
mmio.write(ADDRESS_OFFSET + 0x0C, shift_threshold)

# %%
# Read back widthIn, heightIn, shift_threshold & check
print("Read OpticalFlow address ", hex(ADDRESS_OFFSET + 0x04), ": read out data = ", hex(mmio.read(ADDRESS_OFFSET + 0x04)))
print("Read OpticalFlow address ", hex(ADDRESS_OFFSET + 0x08), ": read out data = ", hex(mmio.read(ADDRESS_OFFSET + 0x08)))
print("Read OpticalFlow address ", hex(ADDRESS_OFFSET + 0x0C), ": read out data = ", hex(mmio.read(ADDRESS_OFFSET + 0x0C)))
# Out:
# Read OpticalFlow address  0x4 : read out data =  0x400
# Read OpticalFlow address  0x8 : read out data =  0x1b4
# Read OpticalFlow address  0xc : read out data =  0x69

# %%
# Program ap_start = 1
###mmio.write(ADDRESS_OFFSET, 0x00000001)

# %%
test_length = TST_FRAME_WIDTH*TST_FRAME_HEIGHT

# %%
# Allocation userDMA s2m memory
updma_buf_s2m = allocate(shape=(TST_FRAME_WIDTH*TST_FRAME_HEIGHT*3,), dtype=np.uint32)
print("updma_buf_s2m.device_address: ", hex(updma_buf_s2m.device_address))

s2m_BASE_ADDRESS = updma_buf_s2m.device_address
s2m_ADDRESS_RANGE = 0x1000
s2m_buf_mmio = MMIO(s2m_BASE_ADDRESS, s2m_ADDRESS_RANGE)

# userDMA Configuration
ADDRESS_OFFSET = PL_UPDMA # 0x9000
# exit clear operation
mmio.write(ADDRESS_OFFSET + 0x20, 0x00000000)
# disable to clear
mmio.write(ADDRESS_OFFSET + 0x30, 0x00000000)
# set buffer length
mmio.write(ADDRESS_OFFSET + 0x28, test_length*3)
# set buffer low
mmio.write(ADDRESS_OFFSET + 0x38, updma_buf_s2m.device_address)
# set buffer high
mmio.write(ADDRESS_OFFSET + 0x3C, 0x00000000)
# Out:
# updma_buf_s2m.device_address:  0x16900000

# %%
ADDRESS_OFFSET = PL_UPDMA # 0x9000
print("mmio.read(ADDRESS_OFFSET+0x00): ", hex(mmio.read(ADDRESS_OFFSET+0x00)))
print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))
print("mmio.read(ADDRESS_OFFSET+0x20): ", hex(mmio.read(ADDRESS_OFFSET+0x20)))
print("mmio.read(ADDRESS_OFFSET+0x28): ", hex(mmio.read(ADDRESS_OFFSET+0x28)))
print("mmio.read(ADDRESS_OFFSET+0x30): ", hex(mmio.read(ADDRESS_OFFSET+0x30)))
print("mmio.read(ADDRESS_OFFSET+0x38): ", hex(mmio.read(ADDRESS_OFFSET+0x38)))
print("mmio.read(ADDRESS_OFFSET+0x3C): ", hex(mmio.read(ADDRESS_OFFSET+0x3C)))
# Out:
# mmio.read(ADDRESS_OFFSET+0x00):  0x4
# mmio.read(ADDRESS_OFFSET+0x10):  0x0
# mmio.read(ADDRESS_OFFSET+0x20):  0x0
# mmio.read(ADDRESS_OFFSET+0x28):  0x147000
# mmio.read(ADDRESS_OFFSET+0x30):  0x0
# mmio.read(ADDRESS_OFFSET+0x38):  0x16900000
# mmio.read(ADDRESS_OFFSET+0x3C):  0x0

# %%
# Allocation userDMA m2s memory
updma_buf_m2s = allocate(shape=(TST_FRAME_WIDTH*TST_FRAME_HEIGHT,), dtype=np.uint32)
print("updma_buf_m2s.device_address: ", hex(updma_buf_m2s.device_address))

# set input data
frame1_pointer = open("frame1.hex", "r")
frame2_pointer = open("frame2.hex", "r")
frame3_pointer = open("frame3.hex", "r")
frame4_pointer = open("frame4.hex", "r")
for i in range(TST_FRAME_WIDTH*TST_FRAME_HEIGHT):
    frame1_value = int(frame1_pointer.readline().strip('\n'),16)
    frame2_value = int(frame2_pointer.readline().strip('\n'),16)
    frame3_value = int(frame3_pointer.readline().strip('\n'),16)
    frame4_value = int(frame4_pointer.readline().strip('\n'),16)
    updma_buf_m2s[i] = (frame4_value<<24) + (frame3_value<<16) + (frame2_value<<8) + frame1_value
    # print(hex((frame4_value<<24) + (frame3_value<<16) + (frame2_value<<8) + frame1_value))

frame1_pointer.close()
frame2_pointer.close()
frame3_pointer.close()
frame4_pointer.close()

m2s_BASE_ADDRESS = updma_buf_m2s.device_address
m2s_ADDRESS_RANGE = 0x1000
m2s_buf_mmio = MMIO(m2s_BASE_ADDRESS, m2s_ADDRESS_RANGE)

# userDMA Configuration
ADDRESS_OFFSET = PL_UPDMA # 0x9000
# exit clear operation
mmio.write(ADDRESS_OFFSET + 0x78, 0x00000000)
# disable to clear
mmio.write(ADDRESS_OFFSET + 0x88, 0x00000000)
# set buffer length
mmio.write(ADDRESS_OFFSET + 0x80, TST_FRAME_WIDTH*TST_FRAME_HEIGHT)
# set buffer low
mmio.write(ADDRESS_OFFSET + 0x5C, updma_buf_m2s.device_address)
# set buffer high
mmio.write(ADDRESS_OFFSET + 0x60, 0x00000000)
# Out:
# updma_buf_m2s.device_address:  0x16f00000

# %%
ADDRESS_OFFSET = PL_UPDMA # 0x9000
print("mmio.read(ADDRESS_OFFSET+0x78): ", hex(mmio.read(ADDRESS_OFFSET+0x78)))
print("mmio.read(ADDRESS_OFFSET+0x88): ", hex(mmio.read(ADDRESS_OFFSET+0x88)))
print("mmio.read(ADDRESS_OFFSET+0x80): ", hex(mmio.read(ADDRESS_OFFSET+0x80)))
print("mmio.read(ADDRESS_OFFSET+0x5C): ", hex(mmio.read(ADDRESS_OFFSET+0x5C)))
print("mmio.read(ADDRESS_OFFSET+0x60): ", hex(mmio.read(ADDRESS_OFFSET+0x60)))
# Out:
# mmio.read(ADDRESS_OFFSET+0x78):  0x0
# mmio.read(ADDRESS_OFFSET+0x88):  0x0
# mmio.read(ADDRESS_OFFSET+0x80):  0x6d000
# mmio.read(ADDRESS_OFFSET+0x5C):  0x16f00000
# mmio.read(ADDRESS_OFFSET+0x60):  0x0

# %%
# PL_UPDMA, set ap_start
mmio.write(PL_UPDMA, 0x00000001)

# %%
# Check userDMA Done
keepChk = True
while keepChk:
    if mmio.read(PL_UPDMA + 0x10) == 0x00000001:
        keepChk = False
print("[Congradulations] Read userDMA buffer transfer done, address ",hex(PL_UPDMA + 0x10), ": read out data = 1")

# %%
print("userDMA buffer transfer done: ", hex(mmio.read(PL_UPDMA + 0x10)))
# Out:
# userDMA buffer transfer done:  0x0

# %%
ADDRESS_OFFSET = PL_UPDMA # 0x9000
print("mmio.read(ADDRESS_OFFSET+0x00): ", hex(mmio.read(ADDRESS_OFFSET+0x00)))
print("mmio.read(ADDRESS_OFFSET+0x10): ", hex(mmio.read(ADDRESS_OFFSET+0x10)))
print("mmio.read(ADDRESS_OFFSET+0x20): ", hex(mmio.read(ADDRESS_OFFSET+0x20)))
print("mmio.read(ADDRESS_OFFSET+0x28): ", hex(mmio.read(ADDRESS_OFFSET+0x28)))
print("mmio.read(ADDRESS_OFFSET+0x30): ", hex(mmio.read(ADDRESS_OFFSET+0x30)))
print("mmio.read(ADDRESS_OFFSET+0x38): ", hex(mmio.read(ADDRESS_OFFSET+0x38)))
print("mmio.read(ADDRESS_OFFSET+0x3C): ", hex(mmio.read(ADDRESS_OFFSET+0x3C)))
# Out:
# mmio.read(ADDRESS_OFFSET+0x00):  0x1
# mmio.read(ADDRESS_OFFSET+0x10):  0x0
# mmio.read(ADDRESS_OFFSET+0x20):  0x0
# mmio.read(ADDRESS_OFFSET+0x28):  0x147000
# mmio.read(ADDRESS_OFFSET+0x30):  0x0
# mmio.read(ADDRESS_OFFSET+0x38):  0x16900000
# mmio.read(ADDRESS_OFFSET+0x3C):  0x0

# %%
# print out updma_buf_s2m
for i in range(test_length*3):
    print("updma_buf_s2m[", i, "] = ", hex(updma_buf_s2m[i]))
# Out:
# updma_buf_s2m[ 0 ] =  0x0
# updma_buf_s2m[ 1 ] =  0x0
# updma_buf_s2m[ 2 ] =  0x0
# updma_buf_s2m[ 3 ] =  0x0
# updma_buf_s2m[ 4 ] =  0x0
# updma_buf_s2m[ 5 ] =  0x0
# updma_buf_s2m[ 6 ] =  0x0
# updma_buf_s2m[ 7 ] =  0x0
# updma_buf_s2m[ 8 ] =  0x0
# updma_buf_s2m[ 9 ] =  0x0
# updma_buf_s2m[ 10 ] =  0x0
# updma_buf_s2m[ 11 ] =  0x0
# updma_buf_s2m[ 12 ] =  0x0
# updma_buf_s2m[ 13 ] =  0x0
# updma_buf_s2m[ 14 ] =  0x0
# updma_buf_s2m[ 15 ] =  0x0
# updma_buf_s2m[ 16 ] =  0x0
# updma_buf_s2m[ 17 ] =  0x0
# updma_buf_s2m[ 18 ] =  0x0
# updma_buf_s2m[ 19 ] =  0x0
# updma_buf_s2m[ 20 ] =  0x0
# updma_buf_s2m[ 21 ] =  0x0
# updma_buf_s2m[ 22 ] =  0x0
# updma_buf_s2m[ 23 ] =  0x0
# updma_buf_s2m[ 24 ] =  0x0
# updma_buf_s2m[ 25 ] =  0x0
# updma_buf_s2m[ 26 ] =  0x0
# updma_buf_s2m[ 27 ] =  0x0
# updma_buf_s2m[ 28 ] =  0x0
# updma_buf_s2m[ 29 ] =  0x0
# updma_buf_s2m[ 30 ] =  0x0
# updma_buf_s2m[ 31 ] =  0x0
# updma_buf_s2m[ 32 ] =  0x0
# updma_buf_s2m[ 33 ] =  0x0
# updma_buf_s2m[ 34 ] =  0x0
# updma_buf_s2m[ 35 ] =  0x0
# updma_buf_s2m[ 36 ] =  0x0
# updma_buf_s2m[ 37 ] =  0x0
# updma_buf_s2m[ 38 ] =  0x0
# updma_buf_s2m[ 39 ] =  0x0
# updma_buf_s2m[ 40 ] =  0x0
# updma_buf_s2m[ 41 ] =  0x0
# updma_buf_s2m[ 42 ] =  0x0
# updma_buf_s2m[ 43 ] =  0x0
# updma_buf_s2m[ 44 ] =  0x0
# updma_buf_s2m[ 45 ] =  0x0
# updma_buf_s2m[ 46 ] =  0x0
# updma_buf_s2m[ 47 ] =  0x0
# updma_buf_s2m[ 48 ] =  0x0
# updma_buf_s2m[ 49 ] =  0x0
# updma_buf_s2m[ 50 ] =  0x0
# updma_buf_s2m[ 51 ] =  0x0
# updma_buf_s2m[ 52 ] =  0x0
# updma_buf_s2m[ 53 ] =  0x0
# updma_buf_s2m[ 54 ] =  0x0
# updma_buf_s2m[ 55 ] =  0x0
# updma_buf_s2m[ 56 ] =  0x0
# updma_buf_s2m[ 57 ] =  0x0
# updma_buf_s2m[ 58 ] =  0x0
# updma_buf_s2m[ 59 ] =  0x0
# updma_buf_s2m[ 60 ] =  0x0
# updma_buf_s2m[ 61 ] =  0x0
# updma_buf_s2m[ 62 ] =  0x0
# updma_buf_s2m[ 63 ] =  0x0
# updma_buf_s2m[ 64 ] =  0x0
# updma_buf_s2m[ 65 ] =  0x0
# updma_buf_s2m[ 66 ] =  0x0
# updma_buf_s2m[ 67 ] =  0x0
# updma_buf_s2m[ 68 ] =  0x0
# updma_buf_s2m[ 69 ] =  0x0
# updma_buf_s2m[ 70 ] =  0x0
# updma_buf_s2m[ 71 ] =  0x0
# updma_buf_s2m[ 72 ] =  0x0
# updma_buf_s2m[ 73 ] =  0x0
# updma_buf_s2m[ 74 ] =  0x0
# updma_buf_s2m[ 75 ] =  0x0
# updma_buf_s2m[ 76 ] =  0x0
# updma_buf_s2m[ 77 ] =  0x0
# updma_buf_s2m[ 78 ] =  0x0
# updma_buf_s2m[ 79 ] =  0x0
# updma_buf_s2m[ 80 ] =  0x0
# updma_buf_s2m[ 81 ] =  0x0
# updma_buf_s2m[ 82 ] =  0x0
# updma_buf_s2m[ 83 ] =  0x0
# updma_buf_s2m[ 84 ] =  0x0
# updma_buf_s2m[ 85 ] =  0x0
# updma_buf_s2m[ 86 ] =  0x0
# updma_buf_s2m[ 87 ] =  0x0
# updma_buf_s2m[ 88 ] =  0x0
# updma_buf_s2m[ 89 ] =  0x0
# updma_buf_s2m[ 90 ] =  0x0
# updma_buf_s2m[ 91 ] =  0x0
# updma_buf_s2m[ 92 ] =  0x0
# updma_buf_s2m[ 93 ] =  0x0
# updma_buf_s2m[ 94 ] =  0x0
# updma_buf_s2m[ 95 ] =  0x0
# updma_buf_s2m[ 96 ] =  0x0
# updma_buf_s2m[ 97 ] =  0x0
# updma_buf_s2m[ 98 ] =  0x0
# updma_buf_s2m[ 99 ] =  0x0
# updma_buf_s2m[ 100 ] =  0x0
# updma_buf_s2m[ 101 ] =  0x0
# updma_buf_s2m[ 102 ] =  0x0
# updma_buf_s2m[ 103 ] =  0x0
# updma_buf_s2m[ 104 ] =  0x0
# updma_buf_s2m[ 105 ] =  0x0
# updma_buf_s2m[ 106 ] =  0x0
# updma_buf_s2m[ 107 ] =  0x0
# updma_buf_s2m[ 108 ] =  0x0
# updma_buf_s2m[ 109 ] =  0x0
# updma_buf_s2m[ 110 ] =  0x0
# updma_buf_s2m[ 111 ] =  0x0
# updma_buf_s2m[ 112 ] =  0x0
# updma_buf_s2m[ 113 ] =  0x0
# updma_buf_s2m[ 114 ] =  0x0
# updma_buf_s2m[ 115 ] =  0x0
# updma_buf_s2m[ 116 ] =  0x0
# updma_buf_s2m[ 117 ] =  0x0
# updma_buf_s2m[ 118 ] =  0x0
# updma_buf_s2m[ 119 ] =  0x0
# updma_buf_s2m[ 120 ] =  0x0
# updma_buf_s2m[ 121 ] =  0x0
# updma_buf_s2m[ 122 ] =  0x0
# updma_buf_s2m[ 123 ] =  0x0
# updma_buf_s2m[ 124 ] =  0x0
# updma_buf_s2m[ 125 ] =  0x0
# updma_buf_s2m[ 126 ] =  0x0
# updma_buf_s2m[ 127 ] =  0x0
# updma_buf_s2m[ 128 ] =  0x0
# updma_buf_s2m[ 129 ] =  0x0
# updma_buf_s2m[ 130 ] =  0x0
# updma_buf_s2m[ 131 ] =  0x0
# updma_buf_s2m[ 132 ] =  0x0
# updma_buf_s2m[ 133 ] =  0x0
# updma_buf_s2m[ 134 ] =  0x0
# updma_buf_s2m[ 135 ] =  0x0
# updma_buf_s2m[ 136 ] =  0x0
# updma_buf_s2m[ 137 ] =  0x0
# updma_buf_s2m[ 138 ] =  0x0
# updma_buf_s2m[ 139 ] =  0x0
# updma_buf_s2m[ 140 ] =  0x0
# updma_buf_s2m[ 141 ] =  0x0
# updma_buf_s2m[ 142 ] =  0x0
# updma_buf_s2m[ 143 ] =  0x0
# updma_buf_s2m[ 144 ] =  0x0
# updma_buf_s2m[ 145 ] =  0x0
# updma_buf_s2m[ 146 ] =  0x0
# updma_buf_s2m[ 147 ] =  0x0
# updma_buf_s2m[ 148 ] =  0x0
# updma_buf_s2m[ 149 ] =  0x0
# updma_buf_s2m[ 150 ] =  0x0
# updma_buf_s2m[ 151 ] =  0x0
# updma_buf_s2m[ 152 ] =  0x0
# updma_buf_s2m[ 153 ] =  0x0
# updma_buf_s2m[ 154 ] =  0x0
# updma_buf_s2m[ 155 ] =  0x0
# updma_buf_s2m[ 156 ] =  0x0
# updma_buf_s2m[ 157 ] =  0x0
# updma_buf_s2m[ 158 ] =  0x0
# updma_buf_s2m[ 159 ] =  0x0
# updma_buf_s2m[ 160 ] =  0x0
# updma_buf_s2m[ 161 ] =  0x0
# updma_buf_s2m[ 162 ] =  0x0
# updma_buf_s2m[ 163 ] =  0x0
# updma_buf_s2m[ 164 ] =  0x0
# updma_buf_s2m[ 165 ] =  0x0
# updma_buf_s2m[ 166 ] =  0x0
# updma_buf_s2m[ 167 ] =  0x0
# updma_buf_s2m[ 168 ] =  0x0
# updma_buf_s2m[ 169 ] =  0x0
# updma_buf_s2m[ 170 ] =  0x0
# updma_buf_s2m[ 171 ] =  0x0
# updma_buf_s2m[ 172 ] =  0x0
# updma_buf_s2m[ 173 ] =  0x0
# updma_buf_s2m[ 174 ] =  0x0
# updma_buf_s2m[ 175 ] =  0x0
# updma_buf_s2m[ 176 ] =  0x0
# updma_buf_s2m[ 177 ] =  0x0
# updma_buf_s2m[ 178 ] =  0x0
# updma_buf_s2m[ 179 ] =  0x0
# updma_buf_s2m[ 180 ] =  0x0
# updma_buf_s2m[ 181 ] =  0x0
# updma_buf_s2m[ 182 ] =  0x0
# updma_buf_s2m[ 183 ] =  0x0
# updma_buf_s2m[ 184 ] =  0x0
# updma_buf_s2m[ 185 ] =  0x0
# updma_buf_s2m[ 186 ] =  0x0
# updma_buf_s2m[ 187 ] =  0x0
# updma_buf_s2m[ 188 ] =  0x0
# updma_buf_s2m[ 189 ] =  0x0
# updma_buf_s2m[ 190 ] =  0x0
# updma_buf_s2m[ 191 ] =  0x0
# updma_buf_s2m[ 192 ] =  0x0
# updma_buf_s2m[ 193 ] =  0x0
# updma_buf_s2m[ 194 ] =  0x0
# updma_buf_s2m[ 195 ] =  0x0
# updma_buf_s2m[ 196 ] =  0x0
# updma_buf_s2m[ 197 ] =  0x0
# updma_buf_s2m[ 198 ] =  0x0
# updma_buf_s2m[ 199 ] =  0x0
# updma_buf_s2m[ 200 ] =  0x0
# updma_buf_s2m[ 201 ] =  0x0
# updma_buf_s2m[ 202 ] =  0x0
# updma_buf_s2m[ 203 ] =  0x0
# updma_buf_s2m[ 204 ] =  0x0
# updma_buf_s2m[ 205 ] =  0x0
# updma_buf_s2m[ 206 ] =  0x0
# updma_buf_s2m[ 207 ] =  0x0
# updma_buf_s2m[ 208 ] =  0x0
# updma_buf_s2m[ 209 ] =  0x0
# updma_buf_s2m[ 210 ] =  0x0
# updma_buf_s2m[ 211 ] =  0x0
# updma_buf_s2m[ 212 ] =  0x0
# updma_buf_s2m[ 213 ] =  0x0
# updma_buf_s2m[ 214 ] =  0x0
# updma_buf_s2m[ 215 ] =  0x0
# updma_buf_s2m[ 216 ] =  0x0
# updma_buf_s2m[ 217 ] =  0x0
# updma_buf_s2m[ 218 ] =  0x0
# updma_buf_s2m[ 219 ] =  0x0
# updma_buf_s2m[ 220 ] =  0x0
# updma_buf_s2m[ 221 ] =  0x0
# updma_buf_s2m[ 222 ] =  0x0
# updma_buf_s2m[ 223 ] =  0x0
# updma_buf_s2m[ 224 ] =  0x0
# updma_buf_s2m[ 225 ] =  0x0
# updma_buf_s2m[ 226 ] =  0x0
# updma_buf_s2m[ 227 ] =  0x0
# updma_buf_s2m[ 228 ] =  0x0
# updma_buf_s2m[ 229 ] =  0x0
# updma_buf_s2m[ 230 ] =  0x0
# updma_buf_s2m[ 231 ] =  0x0
# updma_buf_s2m[ 232 ] =  0x0
# updma_buf_s2m[ 233 ] =  0x0
# updma_buf_s2m[ 234 ] =  0x0
# updma_buf_s2m[ 235 ] =  0x0
# updma_buf_s2m[ 236 ] =  0x0
# updma_buf_s2m[ 237 ] =  0x0
# updma_buf_s2m[ 238 ] =  0x0
# updma_buf_s2m[ 239 ] =  0x0
# updma_buf_s2m[ 240 ] =  0x0
# updma_buf_s2m[ 241 ] =  0x0
# updma_buf_s2m[ 242 ] =  0x0
# updma_buf_s2m[ 243 ] =  0x0
# updma_buf_s2m[ 244 ] =  0x0
# updma_buf_s2m[ 245 ] =  0x0
# updma_buf_s2m[ 246 ] =  0x0
# updma_buf_s2m[ 247 ] =  0x0
# updma_buf_s2m[ 248 ] =  0x0
# updma_buf_s2m[ 249 ] =  0x0
# updma_buf_s2m[ 250 ] =  0x0
# updma_buf_s2m[ 251 ] =  0x0
# updma_buf_s2m[ 252 ] =  0x0
# updma_buf_s2m[ 253 ] =  0x0
# updma_buf_s2m[ 254 ] =  0x0
# updma_buf_s2m[ 255 ] =  0x0
# updma_buf_s2m[ 256 ] =  0x0
# updma_buf_s2m[ 257 ] =  0x0
# updma_buf_s2m[ 258 ] =  0x0
# updma_buf_s2m[ 259 ] =  0x0
# updma_buf_s2m[ 260 ] =  0x0
# updma_buf_s2m[ 261 ] =  0x0
# updma_buf_s2m[ 262 ] =  0x0
# updma_buf_s2m[ 263 ] =  0x0
# updma_buf_s2m[ 264 ] =  0x0
# updma_buf_s2m[ 265 ] =  0x0
# updma_buf_s2m[ 266 ] =  0x0
# updma_buf_s2m[ 267 ] =  0x0
# updma_buf_s2m[ 268 ] =  0x0
# updma_buf_s2m[ 269 ] =  0x0
# updma_buf_s2m[ 270 ] =  0x0
# updma_buf_s2m[ 271 ] =  0x0
# updma_buf_s2m[ 272 ] =  0x0
# updma_buf_s2m[ 273 ] =  0x0
# updma_buf_s2m[ 274 ] =  0x0
# updma_buf_s2m[ 275 ] =  0x0
# updma_buf_s2m[ 276 ] =  0x0
# updma_buf_s2m[ 277 ] =  0x0
# updma_buf_s2m[ 278 ] =  0x0
# updma_buf_s2m[ 279 ] =  0x0
# updma_buf_s2m[ 280 ] =  0x0
# updma_buf_s2m[ 281 ] =  0x0
# updma_buf_s2m[ 282 ] =  0x0
# updma_buf_s2m[ 283 ] =  0x0
# updma_buf_s2m[ 284 ] =  0x0
# updma_buf_s2m[ 285 ] =  0x0
# updma_buf_s2m[ 286 ] =  0x0
# updma_buf_s2m[ 287 ] =  0x0
# updma_buf_s2m[ 288 ] =  0x0
# updma_buf_s2m[ 289 ] =  0x0
# updma_buf_s2m[ 290 ] =  0x0
# updma_buf_s2m[ 291 ] =  0x0
# updma_buf_s2m[ 292 ] =  0x0
# updma_buf_s2m[ 293 ] =  0x0
# updma_buf_s2m[ 294 ] =  0x0
# updma_buf_s2m[ 295 ] =  0x0
# updma_buf_s2m[ 296 ] =  0x0
# updma_buf_s2m[ 297 ] =  0x0
# updma_buf_s2m[ 298 ] =  0x0
# updma_buf_s2m[ 299 ] =  0x0
# updma_buf_s2m[ 300 ] =  0x0
# updma_buf_s2m[ 301 ] =  0x0
# updma_buf_s2m[ 302 ] =  0x0
# updma_buf_s2m[ 303 ] =  0x0
# updma_buf_s2m[ 304 ] =  0x0
# updma_buf_s2m[ 305 ] =  0x0
# updma_buf_s2m[ 306 ] =  0x0
# updma_buf_s2m[ 307 ] =  0x0
# updma_buf_s2m[ 308 ] =  0x0
# updma_buf_s2m[ 309 ] =  0x0
# updma_buf_s2m[ 310 ] =  0x0
# updma_buf_s2m[ 311 ] =  0x0
# updma_buf_s2m[ 312 ] =  0x0
# updma_buf_s2m[ 313 ] =  0x0
# updma_buf_s2m[ 314 ] =  0x0
# updma_buf_s2m[ 315 ] =  0x0
# updma_buf_s2m[ 316 ] =  0x0
# updma_buf_s2m[ 317 ] =  0x0
# updma_buf_s2m[ 318 ] =  0x0
# updma_buf_s2m[ 319 ] =  0x0
# updma_buf_s2m[ 320 ] =  0x0
# updma_buf_s2m[ 321 ] =  0x0
# updma_buf_s2m[ 322 ] =  0x0
# updma_buf_s2m[ 323 ] =  0x0
# updma_buf_s2m[ 324 ] =  0x0
# updma_buf_s2m[ 325 ] =  0x0
# updma_buf_s2m[ 326 ] =  0x0
# updma_buf_s2m[ 327 ] =  0x0
# updma_buf_s2m[ 328 ] =  0x0
# updma_buf_s2m[ 329 ] =  0x0
# updma_buf_s2m[ 330 ] =  0x0
# updma_buf_s2m[ 331 ] =  0x0
# updma_buf_s2m[ 332 ] =  0x0
# updma_buf_s2m[ 333 ] =  0x0
# updma_buf_s2m[ 334 ] =  0x0
# updma_buf_s2m[ 335 ] =  0x0
# updma_buf_s2m[ 336 ] =  0x0
# updma_buf_s2m[ 337 ] =  0x0
# updma_buf_s2m[ 338 ] =  0x0
# updma_buf_s2m[ 339 ] =  0x0
# updma_buf_s2m[ 340 ] =  0x0
# updma_buf_s2m[ 341 ] =  0x0
# updma_buf_s2m[ 342 ] =  0x0
# updma_buf_s2m[ 343 ] =  0x0
# updma_buf_s2m[ 344 ] =  0x0
# updma_buf_s2m[ 345 ] =  0x0
# updma_buf_s2m[ 346 ] =  0x0
# updma_buf_s2m[ 347 ] =  0x0
# updma_buf_s2m[ 348 ] =  0x0
# updma_buf_s2m[ 349 ] =  0x0
# updma_buf_s2m[ 350 ] =  0x0
# updma_buf_s2m[ 351 ] =  0x0
# updma_buf_s2m[ 352 ] =  0x0
# updma_buf_s2m[ 353 ] =  0x0
# updma_buf_s2m[ 354 ] =  0x0
# updma_buf_s2m[ 355 ] =  0x0
# updma_buf_s2m[ 356 ] =  0x0
# updma_buf_s2m[ 357 ] =  0x0
# updma_buf_s2m[ 358 ] =  0x0
# updma_buf_s2m[ 359 ] =  0x0
# updma_buf_s2m[ 360 ] =  0x0
# updma_buf_s2m[ 361 ] =  0x0
# updma_buf_s2m[ 362 ] =  0x0
# updma_buf_s2m[ 363 ] =  0x0
# updma_buf_s2m[ 364 ] =  0x0
# updma_buf_s2m[ 365 ] =  0x0
# updma_buf_s2m[ 366 ] =  0x0
# updma_buf_s2m[ 367 ] =  0x0
# updma_buf_s2m[ 368 ] =  0x0
# updma_buf_s2m[ 369 ] =  0x0
# updma_buf_s2m[ 370 ] =  0x0
# updma_buf_s2m[ 371 ] =  0x0
# updma_buf_s2m[ 372 ] =  0x0
# updma_buf_s2m[ 373 ] =  0x0
# updma_buf_s2m[ 374 ] =  0x0
# updma_buf_s2m[ 375 ] =  0x0
# updma_buf_s2m[ 376 ] =  0x0
# updma_buf_s2m[ 377 ] =  0x0
# updma_buf_s2m[ 378 ] =  0x0
# updma_buf_s2m[ 379 ] =  0x0
# updma_buf_s2m[ 380 ] =  0x0
# updma_buf_s2m[ 381 ] =  0x0
# updma_buf_s2m[ 382 ] =  0x0
# updma_buf_s2m[ 383 ] =  0x0
# updma_buf_s2m[ 384 ] =  0x0
# updma_buf_s2m[ 385 ] =  0x0
# updma_buf_s2m[ 386 ] =  0x0
# updma_buf_s2m[ 387 ] =  0x0
# updma_buf_s2m[ 388 ] =  0x0
# updma_buf_s2m[ 389 ] =  0x0
# updma_buf_s2m[ 390 ] =  0x0
# updma_buf_s2m[ 391 ] =  0x0
# updma_buf_s2m[ 392 ] =  0x0
# updma_buf_s2m[ 393 ] =  0x0
# updma_buf_s2m[ 394 ] =  0x0
# updma_buf_s2m[ 395 ] =  0x0
# updma_buf_s2m[ 396 ] =  0x0
# updma_buf_s2m[ 397 ] =  0x0
# updma_buf_s2m[ 398 ] =  0x0
# updma_buf_s2m[ 399 ] =  0x0
# updma_buf_s2m[ 400 ] =  0x0
# updma_buf_s2m[ 401 ] =  0x0
# updma_buf_s2m[ 402 ] =  0x0
# updma_buf_s2m[ 403 ] =  0x0
# updma_buf_s2m[ 404 ] =  0x0
# updma_buf_s2m[ 405 ] =  0x0
# updma_buf_s2m[ 406 ] =  0x0
# updma_buf_s2m[ 407 ] =  0x0
# updma_buf_s2m[ 408 ] =  0x0
# updma_buf_s2m[ 409 ] =  0x0
# updma_buf_s2m[ 410 ] =  0x0
# updma_buf_s2m[ 411 ] =  0x0
# updma_buf_s2m[ 412 ] =  0x0
# updma_buf_s2m[ 413 ] =  0x0
# updma_buf_s2m[ 414 ] =  0x0
# updma_buf_s2m[ 415 ] =  0x0
# updma_buf_s2m[ 416 ] =  0x0
# updma_buf_s2m[ 417 ] =  0x0
# updma_buf_s2m[ 418 ] =  0x0
# updma_buf_s2m[ 419 ] =  0x0
# updma_buf_s2m[ 420 ] =  0x0
# updma_buf_s2m[ 421 ] =  0x0
# updma_buf_s2m[ 422 ] =  0x0
# updma_buf_s2m[ 423 ] =  0x0
# updma_buf_s2m[ 424 ] =  0x0
# updma_buf_s2m[ 425 ] =  0x0
# updma_buf_s2m[ 426 ] =  0x0
# updma_buf_s2m[ 427 ] =  0x0
# updma_buf_s2m[ 428 ] =  0x0
# updma_buf_s2m[ 429 ] =  0x0
# updma_buf_s2m[ 430 ] =  0x0
# updma_buf_s2m[ 431 ] =  0x0
# updma_buf_s2m[ 432 ] =  0x0
# updma_buf_s2m[ 433 ] =  0x0
# updma_buf_s2m[ 434 ] =  0x0
# updma_buf_s2m[ 435 ] =  0x0
# updma_buf_s2m[ 436 ] =  0x0
# updma_buf_s2m[ 437 ] =  0x0
# updma_buf_s2m[ 438 ] =  0x0
# updma_buf_s2m[ 439 ] =  0x0
# updma_buf_s2m[ 440 ] =  0x0
# updma_buf_s2m[ 441 ] =  0x0
# updma_buf_s2m[ 442 ] =  0x0
# updma_buf_s2m[ 443 ] =  0x0
# updma_buf_s2m[ 444 ] =  0x0
# updma_buf_s2m[ 445 ] =  0x0
# updma_buf_s2m[ 446 ] =  0x0
# updma_buf_s2m[ 447 ] =  0x0
# updma_buf_s2m[ 448 ] =  0x0
# updma_buf_s2m[ 449 ] =  0x0
# updma_buf_s2m[ 450 ] =  0x0
# updma_buf_s2m[ 451 ] =  0x0
# updma_buf_s2m[ 452 ] =  0x0
# updma_buf_s2m[ 453 ] =  0x0
# updma_buf_s2m[ 454 ] =  0x0
# updma_buf_s2m[ 455 ] =  0x0
# updma_buf_s2m[ 456 ] =  0x0
# updma_buf_s2m[ 457 ] =  0x0
# updma_buf_s2m[ 458 ] =  0x0
# updma_buf_s2m[ 459 ] =  0x0
# updma_buf_s2m[ 460 ] =  0x0
# updma_buf_s2m[ 461 ] =  0x0
# updma_buf_s2m[ 462 ] =  0x0
# updma_buf_s2m[ 463 ] =  0x0
# updma_buf_s2m[ 464 ] =  0x0
# updma_buf_s2m[ 465 ] =  0x0
# updma_buf_s2m[ 466 ] =  0x0
# updma_buf_s2m[ 467 ] =  0x0
# updma_buf_s2m[ 468 ] =  0x0
# updma_buf_s2m[ 469 ] =  0x0
# updma_buf_s2m[ 470 ] =  0x0
# updma_buf_s2m[ 471 ] =  0x0
# updma_buf_s2m[ 472 ] =  0x0
# updma_buf_s2m[ 473 ] =  0x0
# updma_buf_s2m[ 474 ] =  0x0
# updma_buf_s2m[ 475 ] =  0x0
# updma_buf_s2m[ 476 ] =  0x0
# updma_buf_s2m[ 477 ] =  0x0
# updma_buf_s2m[ 478 ] =  0x0
# updma_buf_s2m[ 479 ] =  0x0
# updma_buf_s2m[ 480 ] =  0x0
# updma_buf_s2m[ 481 ] =  0x0
# updma_buf_s2m[ 482 ] =  0x0
# updma_buf_s2m[ 483 ] =  0x0
# updma_buf_s2m[ 484 ] =  0x0
# updma_buf_s2m[ 485 ] =  0x0
# updma_buf_s2m[ 486 ] =  0x0
# updma_buf_s2m[ 487 ] =  0x0
# updma_buf_s2m[ 488 ] =  0x0
# updma_buf_s2m[ 489 ] =  0x0
# updma_buf_s2m[ 490 ] =  0x0
# updma_buf_s2m[ 491 ] =  0x0
# updma_buf_s2m[ 492 ] =  0x0
# updma_buf_s2m[ 493 ] =  0x0
# updma_buf_s2m[ 494 ] =  0x0
# updma_buf_s2m[ 495 ] =  0x0
# updma_buf_s2m[ 496 ] =  0x0
# updma_buf_s2m[ 497 ] =  0x0
# updma_buf_s2m[ 498 ] =  0x0
# updma_buf_s2m[ 499 ] =  0x0
# updma_buf_s2m[ 500 ] =  0x0
# updma_buf_s2m[ 501 ] =  0x0
# updma_buf_s2m[ 502 ] =  0x0
# updma_buf_s2m[ 503 ] =  0x0
# updma_buf_s2m[ 504 ] =  0x0
# updma_buf_s2m[ 505 ] =  0x0
# updma_buf_s2m[ 506 ] =  0x0
# updma_buf_s2m[ 507 ] =  0x0
# updma_buf_s2m[ 508 ] =  0x0
# updma_buf_s2m[ 509 ] =  0x0
# updma_buf_s2m[ 510 ] =  0x0
# updma_buf_s2m[ 511 ] =  0x0
# updma_buf_s2m[ 512 ] =  0x0
# updma_buf_s2m[ 513 ] =  0x0
# updma_buf_s2m[ 514 ] =  0x0
# updma_buf_s2m[ 515 ] =  0x0
# updma_buf_s2m[ 516 ] =  0x0
# updma_buf_s2m[ 517 ] =  0x0
# updma_buf_s2m[ 518 ] =  0x0
# updma_buf_s2m[ 519 ] =  0x0
# updma_buf_s2m[ 520 ] =  0x0
# updma_buf_s2m[ 521 ] =  0x0
# updma_buf_s2m[ 522 ] =  0x0
# updma_buf_s2m[ 523 ] =  0x0
# updma_buf_s2m[ 524 ] =  0x0
# updma_buf_s2m[ 525 ] =  0x0
# updma_buf_s2m[ 526 ] =  0x0
# updma_buf_s2m[ 527 ] =  0x0
# updma_buf_s2m[ 528 ] =  0x0
# updma_buf_s2m[ 529 ] =  0x0
# updma_buf_s2m[ 530 ] =  0x0
# updma_buf_s2m[ 531 ] =  0x0
# updma_buf_s2m[ 532 ] =  0x0
# updma_buf_s2m[ 533 ] =  0x0
# updma_buf_s2m[ 534 ] =  0x0
# updma_buf_s2m[ 535 ] =  0x0
# updma_buf_s2m[ 536 ] =  0x0
# updma_buf_s2m[ 537 ] =  0x0
# updma_buf_s2m[ 538 ] =  0x0
# updma_buf_s2m[ 539 ] =  0x0
# updma_buf_s2m[ 540 ] =  0x0
# updma_buf_s2m[ 541 ] =  0x0
# updma_buf_s2m[ 542 ] =  0x0
# updma_buf_s2m[ 543 ] =  0x0
# updma_buf_s2m[ 544 ] =  0x0
# updma_buf_s2m[ 545 ] =  0x0
# updma_buf_s2m[ 546 ] =  0x0
# updma_buf_s2m[ 547 ] =  0x0
# updma_buf_s2m[ 548 ] =  0x0
# updma_buf_s2m[ 549 ] =  0x0
# updma_buf_s2m[ 550 ] =  0x0
# updma_buf_s2m[ 551 ] =  0x0
# updma_buf_s2m[ 552 ] =  0x0
# updma_buf_s2m[ 553 ] =  0x0
# updma_buf_s2m[ 554 ] =  0x0
# updma_buf_s2m[ 555 ] =  0x0
# updma_buf_s2m[ 556 ] =  0x0
# updma_buf_s2m[ 557 ] =  0x0
# updma_buf_s2m[ 558 ] =  0x0
# updma_buf_s2m[ 559 ] =  0x0
# updma_buf_s2m[ 560 ] =  0x0
# updma_buf_s2m[ 561 ] =  0x0
# updma_buf_s2m[ 562 ] =  0x0
# updma_buf_s2m[ 563 ] =  0x0
# updma_buf_s2m[ 564 ] =  0x0
# updma_buf_s2m[ 565 ] =  0x0
# updma_buf_s2m[ 566 ] =  0x0
# updma_buf_s2m[ 567 ] =  0x0
# updma_buf_s2m[ 568 ] =  0x0
# updma_buf_s2m[ 569 ] =  0x0
# updma_buf_s2m[ 570 ] =  0x0
# updma_buf_s2m[ 571 ] =  0x0
# updma_buf_s2m[ 572 ] =  0x0
# updma_buf_s2m[ 573 ] =  0x0
# updma_buf_s2m[ 574 ] =  0x0
# updma_buf_s2m[ 575 ] =  0x0
# updma_buf_s2m[ 576 ] =  0x0
# updma_buf_s2m[ 577 ] =  0x0
# updma_buf_s2m[ 578 ] =  0x0
# updma_buf_s2m[ 579 ] =  0x0
# updma_buf_s2m[ 580 ] =  0x0
# updma_buf_s2m[ 581 ] =  0x0
# updma_buf_s2m[ 582 ] =  0x0
# updma_buf_s2m[ 583 ] =  0x0
# updma_buf_s2m[ 584 ] =  0x0
# updma_buf_s2m[ 585 ] =  0x0
# updma_buf_s2m[ 586 ] =  0x0
# updma_buf_s2m[ 587 ] =  0x0
# updma_buf_s2m[ 588 ] =  0x0
# updma_buf_s2m[ 589 ] =  0x0
# updma_buf_s2m[ 590 ] =  0x0
# updma_buf_s2m[ 591 ] =  0x0
# updma_buf_s2m[ 592 ] =  0x0
# updma_buf_s2m[ 593 ] =  0x0
# updma_buf_s2m[ 594 ] =  0x0
# updma_buf_s2m[ 595 ] =  0x0
# updma_buf_s2m[ 596 ] =  0x0
# updma_buf_s2m[ 597 ] =  0x0
# updma_buf_s2m[ 598 ] =  0x0
# updma_buf_s2m[ 599 ] =  0x0
# updma_buf_s2m[ 600 ] =  0x0
# updma_buf_s2m[ 601 ] =  0x0
# updma_buf_s2m[ 602 ] =  0x0
# updma_buf_s2m[ 603 ] =  0x0
# updma_buf_s2m[ 604 ] =  0x0
# updma_buf_s2m[ 605 ] =  0x0
# updma_buf_s2m[ 606 ] =  0x0
# updma_buf_s2m[ 607 ] =  0x0
# updma_buf_s2m[ 608 ] =  0x0
# updma_buf_s2m[ 609 ] =  0x0
# updma_buf_s2m[ 610 ] =  0x0
# updma_buf_s2m[ 611 ] =  0x0
# updma_buf_s2m[ 612 ] =  0x0
# updma_buf_s2m[ 613 ] =  0x0
# updma_buf_s2m[ 614 ] =  0x0
# updma_buf_s2m[ 615 ] =  0x0
# updma_buf_s2m[ 616 ] =  0x0
# updma_buf_s2m[ 617 ] =  0x0
# updma_buf_s2m[ 618 ] =  0x0
# updma_buf_s2m[ 619 ] =  0x0
# updma_buf_s2m[ 620 ] =  0x0
# updma_buf_s2m[ 621 ] =  0x0
# updma_buf_s2m[ 622 ] =  0x0
# updma_buf_s2m[ 623 ] =  0x0
# updma_buf_s2m[ 624 ] =  0x0
# updma_buf_s2m[ 625 ] =  0x0
# updma_buf_s2m[ 626 ] =  0x0
# updma_buf_s2m[ 627 ] =  0x0
# updma_buf_s2m[ 628 ] =  0x0
# updma_buf_s2m[ 629 ] =  0x0
# updma_buf_s2m[ 630 ] =  0x0
# updma_buf_s2m[ 631 ] =  0x0
# updma_buf_s2m[ 632 ] =  0x0
# updma_buf_s2m[ 633 ] =  0x0
# updma_buf_s2m[ 634 ] =  0x0
# updma_buf_s2m[ 635 ] =  0x0
# updma_buf_s2m[ 636 ] =  0x0
# updma_buf_s2m[ 637 ] =  0x0
# updma_buf_s2m[ 638 ] =  0x0
# updma_buf_s2m[ 639 ] =  0x0
# updma_buf_s2m[ 640 ] =  0x0
# updma_buf_s2m[ 641 ] =  0x0
# updma_buf_s2m[ 642 ] =  0x0
# updma_buf_s2m[ 643 ] =  0x0
# updma_buf_s2m[ 644 ] =  0x0
# updma_buf_s2m[ 645 ] =  0x0
# updma_buf_s2m[ 646 ] =  0x0
# updma_buf_s2m[ 647 ] =  0x0
# updma_buf_s2m[ 648 ] =  0x0
# updma_buf_s2m[ 649 ] =  0x0
# updma_buf_s2m[ 650 ] =  0x0
# updma_buf_s2m[ 651 ] =  0x0
# updma_buf_s2m[ 652 ] =  0x0
# updma_buf_s2m[ 653 ] =  0x0
# updma_buf_s2m[ 654 ] =  0x0
# updma_buf_s2m[ 655 ] =  0x0
# updma_buf_s2m[ 656 ] =  0x0
# updma_buf_s2m[ 657 ] =  0x0
# updma_buf_s2m[ 658 ] =  0x0
# updma_buf_s2m[ 659 ] =  0x0
# updma_buf_s2m[ 660 ] =  0x0
# updma_buf_s2m[ 661 ] =  0x0
# updma_buf_s2m[ 662 ] =  0x0
# updma_buf_s2m[ 663 ] =  0x0
# updma_buf_s2m[ 664 ] =  0x0
# updma_buf_s2m[ 665 ] =  0x0
# updma_buf_s2m[ 666 ] =  0x0
# updma_buf_s2m[ 667 ] =  0x0
# updma_buf_s2m[ 668 ] =  0x0
# updma_buf_s2m[ 669 ] =  0x0
# updma_buf_s2m[ 670 ] =  0x0
# updma_buf_s2m[ 671 ] =  0x0
# updma_buf_s2m[ 672 ] =  0x0
# updma_buf_s2m[ 673 ] =  0x0
# updma_buf_s2m[ 674 ] =  0x0
# updma_buf_s2m[ 675 ] =  0x0
# updma_buf_s2m[ 676 ] =  0x0
# updma_buf_s2m[ 677 ] =  0x0
# updma_buf_s2m[ 678 ] =  0x0
# updma_buf_s2m[ 679 ] =  0x0
# updma_buf_s2m[ 680 ] =  0x0
# updma_buf_s2m[ 681 ] =  0x0
# updma_buf_s2m[ 682 ] =  0x0
# updma_buf_s2m[ 683 ] =  0x0
# updma_buf_s2m[ 684 ] =  0x0
# updma_buf_s2m[ 685 ] =  0x0
# updma_buf_s2m[ 686 ] =  0x0
# updma_buf_s2m[ 687 ] =  0x0
# updma_buf_s2m[ 688 ] =  0x0
# updma_buf_s2m[ 689 ] =  0x0
# updma_buf_s2m[ 690 ] =  0x0
# updma_buf_s2m[ 691 ] =  0x0
# updma_buf_s2m[ 692 ] =  0x0
# updma_buf_s2m[ 693 ] =  0x0
# updma_buf_s2m[ 694 ] =  0x0
# updma_buf_s2m[ 695 ] =  0x0
# updma_buf_s2m[ 696 ] =  0x0
# updma_buf_s2m[ 697 ] =  0x0
# updma_buf_s2m[ 698 ] =  0x0
# updma_buf_s2m[ 699 ] =  0x0
# updma_buf_s2m[ 700 ] =  0x0
# updma_buf_s2m[ 701 ] =  0x0
# updma_buf_s2m[ 702 ] =  0x0
# updma_buf_s2m[ 703 ] =  0x0
# updma_buf_s2m[ 704 ] =  0x0
# updma_buf_s2m[ 705 ] =  0x0
# updma_buf_s2m[ 706 ] =  0x0
# updma_buf_s2m[ 707 ] =  0x0
# updma_buf_s2m[ 708 ] =  0x0
# updma_buf_s2m[ 709 ] =  0x0
# updma_buf_s2m[ 710 ] =  0x0
# updma_buf_s2m[ 711 ] =  0x0
# updma_buf_s2m[ 712 ] =  0x0
# updma_buf_s2m[ 713 ] =  0x0
# updma_buf_s2m[ 714 ] =  0x0
# updma_buf_s2m[ 715 ] =  0x0
# updma_buf_s2m[ 716 ] =  0x0
# updma_buf_s2m[ 717 ] =  0x0
# updma_buf_s2m[ 718 ] =  0x0
# updma_buf_s2m[ 719 ] =  0x0
# updma_buf_s2m[ 720 ] =  0x0
# updma_buf_s2m[ 721 ] =  0x0
# updma_buf_s2m[ 722 ] =  0x0
# updma_buf_s2m[ 723 ] =  0x0
# updma_buf_s2m[ 724 ] =  0x0
# updma_buf_s2m[ 725 ] =  0x0
# updma_buf_s2m[ 726 ] =  0x0
# updma_buf_s2m[ 727 ] =  0x0
# updma_buf_s2m[ 728 ] =  0x0
# updma_buf_s2m[ 729 ] =  0x0
# updma_buf_s2m[ 730 ] =  0x0
# updma_buf_s2m[ 731 ] =  0x0
# updma_buf_s2m[ 732 ] =  0x0
# updma_buf_s2m[ 733 ] =  0x0
# updma_buf_s2m[ 734 ] =  0x0
# updma_buf_s2m[ 735 ] =  0x0
# updma_buf_s2m[ 736 ] =  0x0
# updma_buf_s2m[ 737 ] =  0x0
# updma_buf_s2m[ 738 ] =  0x0
# updma_buf_s2m[ 739 ] =  0x0
# updma_buf_s2m[ 740 ] =  0x0
# updma_buf_s2m[ 741 ] =  0x0
# updma_buf_s2m[ 742 ] =  0x0
# updma_buf_s2m[ 743 ] =  0x0
# updma_buf_s2m[ 744 ] =  0x0
# updma_buf_s2m[ 745 ] =  0x0
# updma_buf_s2m[ 746 ] =  0x0
# updma_buf_s2m[ 747 ] =  0x0
# updma_buf_s2m[ 748 ] =  0x0
# updma_buf_s2m[ 749 ] =  0x0
# updma_buf_s2m[ 750 ] =  0x0
# updma_buf_s2m[ 751 ] =  0x0
# updma_buf_s2m[ 752 ] =  0x0
# updma_buf_s2m[ 753 ] =  0x0
# updma_buf_s2m[ 754 ] =  0x0
# updma_buf_s2m[ 755 ] =  0x0
# updma_buf_s2m[ 756 ] =  0x0
# updma_buf_s2m[ 757 ] =  0x0
# updma_buf_s2m[ 758 ] =  0x0
# updma_buf_s2m[ 759 ] =  0x0
# updma_buf_s2m[ 760 ] =  0x0
# updma_buf_s2m[ 761 ] =  0x0
# updma_buf_s2m[ 762 ] =  0x0
# updma_buf_s2m[ 763 ] =  0x0
# updma_buf_s2m[ 764 ] =  0x0
# updma_buf_s2m[ 765 ] =  0x0
# updma_buf_s2m[ 766 ] =  0x0
# updma_buf_s2m[ 767 ] =  0x0
# updma_buf_s2m[ 768 ] =  0x0
# updma_buf_s2m[ 769 ] =  0x0
# updma_buf_s2m[ 770 ] =  0x0
# updma_buf_s2m[ 771 ] =  0x0
# updma_buf_s2m[ 772 ] =  0x0
# updma_buf_s2m[ 773 ] =  0x0
# updma_buf_s2m[ 774 ] =  0x0
# updma_buf_s2m[ 775 ] =  0x0
# updma_buf_s2m[ 776 ] =  0x0
# updma_buf_s2m[ 777 ] =  0x0
# updma_buf_s2m[ 778 ] =  0x0
# updma_buf_s2m[ 779 ] =  0x0
# updma_buf_s2m[ 780 ] =  0x0
# updma_buf_s2m[ 781 ] =  0x0
# updma_buf_s2m[ 782 ] =  0x0
# updma_buf_s2m[ 783 ] =  0x0
# updma_buf_s2m[ 784 ] =  0x0
# updma_buf_s2m[ 785 ] =  0x0
# updma_buf_s2m[ 786 ] =  0x0
# updma_buf_s2m[ 787 ] =  0x0
# updma_buf_s2m[ 788 ] =  0x0
# updma_buf_s2m[ 789 ] =  0x0
# updma_buf_s2m[ 790 ] =  0x0
# updma_buf_s2m[ 791 ] =  0x0
# updma_buf_s2m[ 792 ] =  0x0
# updma_buf_s2m[ 793 ] =  0x0
# updma_buf_s2m[ 794 ] =  0x0
# updma_buf_s2m[ 795 ] =  0x0
# updma_buf_s2m[ 796 ] =  0x0
# updma_buf_s2m[ 797 ] =  0x0
# updma_buf_s2m[ 798 ] =  0x0
# updma_buf_s2m[ 799 ] =  0x0
# updma_buf_s2m[ 800 ] =  0x0
# updma_buf_s2m[ 801 ] =  0x0
# updma_buf_s2m[ 802 ] =  0x0
# updma_buf_s2m[ 803 ] =  0x0
# updma_buf_s2m[ 804 ] =  0x0
# updma_buf_s2m[ 805 ] =  0x0
# updma_buf_s2m[ 806 ] =  0x0
# updma_buf_s2m[ 807 ] =  0x0
# updma_buf_s2m[ 808 ] =  0x0
# updma_buf_s2m[ 809 ] =  0x0
# updma_buf_s2m[ 810 ] =  0x0
# updma_buf_s2m[ 811 ] =  0x0
# updma_buf_s2m[ 812 ] =  0x0
# updma_buf_s2m[ 813 ] =  0x0
# updma_buf_s2m[ 814 ] =  0x0
# updma_buf_s2m[ 815 ] =  0x0
# updma_buf_s2m[ 816 ] =  0x0
# updma_buf_s2m[ 817 ] =  0x0
# updma_buf_s2m[ 818 ] =  0x0
# updma_buf_s2m[ 819 ] =  0x0
# updma_buf_s2m[ 820 ] =  0x0
# updma_buf_s2m[ 821 ] =  0x0
# updma_buf_s2m[ 822 ] =  0x0
# updma_buf_s2m[ 823 ] =  0x0
# updma_buf_s2m[ 824 ] =  0x0
# updma_buf_s2m[ 825 ] =  0x0
# updma_buf_s2m[ 826 ] =  0x0
# updma_buf_s2m[ 827 ] =  0x0
# updma_buf_s2m[ 828 ] =  0x0
# updma_buf_s2m[ 829 ] =  0x0
# updma_buf_s2m[ 830 ] =  0x0
# updma_buf_s2m[ 831 ] =  0x0
# updma_buf_s2m[ 832 ] =  0x0
# updma_buf_s2m[ 833 ] =  0x0
# updma_buf_s2m[ 834 ] =  0x0
# updma_buf_s2m[ 835 ] =  0x0
# updma_buf_s2m[ 836 ] =  0x0
# updma_buf_s2m[ 837 ] =  0x0
# updma_buf_s2m[ 838 ] =  0x0
# updma_buf_s2m[ 839 ] =  0x0
# updma_buf_s2m[ 840 ] =  0x0
# updma_buf_s2m[ 841 ] =  0x0
# updma_buf_s2m[ 842 ] =  0x0
# updma_buf_s2m[ 843 ] =  0x0
# updma_buf_s2m[ 844 ] =  0x0
# updma_buf_s2m[ 845 ] =  0x0
# updma_buf_s2m[ 846 ] =  0x0
# updma_buf_s2m[ 847 ] =  0x0
# updma_buf_s2m[ 848 ] =  0x0
# updma_buf_s2m[ 849 ] =  0x0
# updma_buf_s2m[ 850 ] =  0x0
# updma_buf_s2m[ 851 ] =  0x0
# updma_buf_s2m[ 852 ] =  0x0
# updma_buf_s2m[ 853 ] =  0x0
# updma_buf_s2m[ 854 ] =  0x0
# updma_buf_s2m[ 855 ] =  0x0
# updma_buf_s2m[ 856 ] =  0x0
# updma_buf_s2m[ 857 ] =  0x0
# updma_buf_s2m[ 858 ] =  0x0
# updma_buf_s2m[ 859 ] =  0x0
# updma_buf_s2m[ 860 ] =  0x0
# updma_buf_s2m[ 861 ] =  0x0
# updma_buf_s2m[ 862 ] =  0x0
# updma_buf_s2m[ 863 ] =  0x0
# updma_buf_s2m[ 864 ] =  0x0
# updma_buf_s2m[ 865 ] =  0x0
# updma_buf_s2m[ 866 ] =  0x0
# updma_buf_s2m[ 867 ] =  0x0
# updma_buf_s2m[ 868 ] =  0x0
# updma_buf_s2m[ 869 ] =  0x0
# updma_buf_s2m[ 870 ] =  0x0
# updma_buf_s2m[ 871 ] =  0x0
# updma_buf_s2m[ 872 ] =  0x0
# updma_buf_s2m[ 873 ] =  0x0
# updma_buf_s2m[ 874 ] =  0x0
# updma_buf_s2m[ 875 ] =  0x0
# updma_buf_s2m[ 876 ] =  0x0
# updma_buf_s2m[ 877 ] =  0x0
# updma_buf_s2m[ 878 ] =  0x0
# updma_buf_s2m[ 879 ] =  0x0
# updma_buf_s2m[ 880 ] =  0x0
# updma_buf_s2m[ 881 ] =  0x0
# updma_buf_s2m[ 882 ] =  0x0
# updma_buf_s2m[ 883 ] =  0x0
# updma_buf_s2m[ 884 ] =  0x0
# updma_buf_s2m[ 885 ] =  0x0
# updma_buf_s2m[ 886 ] =  0x0
# updma_buf_s2m[ 887 ] =  0x0
# updma_buf_s2m[ 888 ] =  0x0
# updma_buf_s2m[ 889 ] =  0x0
# updma_buf_s2m[ 890 ] =  0x0
# updma_buf_s2m[ 891 ] =  0x0
# updma_buf_s2m[ 892 ] =  0x0
# updma_buf_s2m[ 893 ] =  0x0
# updma_buf_s2m[ 894 ] =  0x0
# updma_buf_s2m[ 895 ] =  0x0
# updma_buf_s2m[ 896 ] =  0x0
# updma_buf_s2m[ 897 ] =  0x0
# updma_buf_s2m[ 898 ] =  0x0
# updma_buf_s2m[ 899 ] =  0x0
# updma_buf_s2m[ 900 ] =  0x0
# updma_buf_s2m[ 901 ] =  0x0
# updma_buf_s2m[ 902 ] =  0x0
# updma_buf_s2m[ 903 ] =  0x0
# updma_buf_s2m[ 904 ] =  0x0
# updma_buf_s2m[ 905 ] =  0x0
# updma_buf_s2m[ 906 ] =  0x0
# updma_buf_s2m[ 907 ] =  0x0
# updma_buf_s2m[ 908 ] =  0x0
# updma_buf_s2m[ 909 ] =  0x0
# updma_buf_s2m[ 910 ] =  0x0
# updma_buf_s2m[ 911 ] =  0x0
# updma_buf_s2m[ 912 ] =  0x0
# updma_buf_s2m[ 913 ] =  0x0
# updma_buf_s2m[ 914 ] =  0x0
# updma_buf_s2m[ 915 ] =  0x0
# updma_buf_s2m[ 916 ] =  0x0
# updma_buf_s2m[ 917 ] =  0x0
# updma_buf_s2m[ 918 ] =  0x0
# updma_buf_s2m[ 919 ] =  0x0
# updma_buf_s2m[ 920 ] =  0x0
# updma_buf_s2m[ 921 ] =  0x0
# updma_buf_s2m[ 922 ] =  0x0
# updma_buf_s2m[ 923 ] =  0x0
# updma_buf_s2m[ 924 ] =  0x0
# updma_buf_s2m[ 925 ] =  0x0
# updma_buf_s2m[ 926 ] =  0x0
# updma_buf_s2m[ 927 ] =  0x0
# updma_buf_s2m[ 928 ] =  0x0
# updma_buf_s2m[ 929 ] =  0x0
# updma_buf_s2m[ 930 ] =  0x0
# updma_buf_s2m[ 931 ] =  0x0
# updma_buf_s2m[ 932 ] =  0x0
# updma_buf_s2m[ 933 ] =  0x0
# updma_buf_s2m[ 934 ] =  0x0
# updma_buf_s2m[ 935 ] =  0x0
# updma_buf_s2m[ 936 ] =  0x0
# updma_buf_s2m[ 937 ] =  0x0
# updma_buf_s2m[ 938 ] =  0x0
# updma_buf_s2m[ 939 ] =  0x0
# updma_buf_s2m[ 940 ] =  0x0
# updma_buf_s2m[ 941 ] =  0x0
# updma_buf_s2m[ 942 ] =  0x0
# updma_buf_s2m[ 943 ] =  0x0
# updma_buf_s2m[ 944 ] =  0x0
# updma_buf_s2m[ 945 ] =  0x0
# updma_buf_s2m[ 946 ] =  0x0
# updma_buf_s2m[ 947 ] =  0x0
# updma_buf_s2m[ 948 ] =  0x0
# updma_buf_s2m[ 949 ] =  0x0
# updma_buf_s2m[ 950 ] =  0x0
# updma_buf_s2m[ 951 ] =  0x0
# updma_buf_s2m[ 952 ] =  0x0
# updma_buf_s2m[ 953 ] =  0x0
# updma_buf_s2m[ 954 ] =  0x0
# updma_buf_s2m[ 955 ] =  0x0
# updma_buf_s2m[ 956 ] =  0x0
# updma_buf_s2m[ 957 ] =  0x0
# updma_buf_s2m[ 958 ] =  0x0
# updma_buf_s2m[ 959 ] =  0x0
# updma_buf_s2m[ 960 ] =  0x0
# updma_buf_s2m[ 961 ] =  0x0
# updma_buf_s2m[ 962 ] =  0x0
# updma_buf_s2m[ 963 ] =  0x0
# updma_buf_s2m[ 964 ] =  0x0
# updma_buf_s2m[ 965 ] =  0x0
# updma_buf_s2m[ 966 ] =  0x0
# updma_buf_s2m[ 967 ] =  0x0
# updma_buf_s2m[ 968 ] =  0x0
# updma_buf_s2m[ 969 ] =  0x0
# updma_buf_s2m[ 970 ] =  0x0
# updma_buf_s2m[ 971 ] =  0x0
# updma_buf_s2m[ 972 ] =  0x0
# updma_buf_s2m[ 973 ] =  0x0
# updma_buf_s2m[ 974 ] =  0x0
# updma_buf_s2m[ 975 ] =  0x0
# updma_buf_s2m[ 976 ] =  0x0
# updma_buf_s2m[ 977 ] =  0x0
# updma_buf_s2m[ 978 ] =  0x0
# updma_buf_s2m[ 979 ] =  0x0
# updma_buf_s2m[ 980 ] =  0x0
# updma_buf_s2m[ 981 ] =  0x0
# updma_buf_s2m[ 982 ] =  0x0
# updma_buf_s2m[ 983 ] =  0x0
# updma_buf_s2m[ 984 ] =  0x0
# updma_buf_s2m[ 985 ] =  0x0
# updma_buf_s2m[ 986 ] =  0x0
# updma_buf_s2m[ 987 ] =  0x0
# updma_buf_s2m[ 988 ] =  0x0
# updma_buf_s2m[ 989 ] =  0x0
# updma_buf_s2m[ 990 ] =  0x0
# updma_buf_s2m[ 991 ] =  0x0
# updma_buf_s2m[ 992 ] =  0x0
# updma_buf_s2m[ 993 ] =  0x0
# updma_buf_s2m[ 994 ] =  0x0
# updma_buf_s2m[ 995 ] =  0x0
# updma_buf_s2m[ 996 ] =  0x0
# updma_buf_s2m[ 997 ] =  0x0
# updma_buf_s2m[ 998 ] =  0x0
# updma_buf_s2m[ 999 ] =  0x0
# updma_buf_s2m[ 1000 ] =  0x0
# updma_buf_s2m[ 1001 ] =  0x0
# updma_buf_s2m[ 1002 ] =  0x0
# updma_buf_s2m[ 1003 ] =  0x0
# updma_buf_s2m[ 1004 ] =  0x0
# updma_buf_s2m[ 1005 ] =  0x0
# updma_buf_s2m[ 1006 ] =  0x0
# updma_buf_s2m[ 1007 ] =  0x0
# updma_buf_s2m[ 1008 ] =  0x0
# updma_buf_s2m[ 1009 ] =  0x0
# updma_buf_s2m[ 1010 ] =  0x0
# updma_buf_s2m[ 1011 ] =  0x0
# updma_buf_s2m[ 1012 ] =  0x0
# updma_buf_s2m[ 1013 ] =  0x0
# updma_buf_s2m[ 1014 ] =  0x0
# updma_buf_s2m[ 1015 ] =  0x0
# updma_buf_s2m[ 1016 ] =  0x0
# updma_buf_s2m[ 1017 ] =  0x0
# updma_buf_s2m[ 1018 ] =  0x0
# updma_buf_s2m[ 1019 ] =  0x0
# updma_buf_s2m[ 1020 ] =  0x0
# updma_buf_s2m[ 1021 ] =  0x0
# updma_buf_s2m[ 1022 ] =  0x0
# updma_buf_s2m[ 1023 ] =  0x0
# updma_buf_s2m[ 1024 ] =  0x0
# updma_buf_s2m[ 1025 ] =  0x0
# updma_buf_s2m[ 1026 ] =  0x0
# updma_buf_s2m[ 1027 ] =  0x0
# updma_buf_s2m[ 1028 ] =  0x0
# updma_buf_s2m[ 1029 ] =  0x0
# updma_buf_s2m[ 1030 ] =  0x0
# updma_buf_s2m[ 1031 ] =  0x0
# updma_buf_s2m[ 1032 ] =  0x0
# updma_buf_s2m[ 1033 ] =  0x0
# updma_buf_s2m[ 1034 ] =  0x0
# updma_buf_s2m[ 1035 ] =  0x0
# updma_buf_s2m[ 1036 ] =  0x0
# updma_buf_s2m[ 1037 ] =  0x0
# updma_buf_s2m[ 1038 ] =  0x0
# updma_buf_s2m[ 1039 ] =  0x0
# updma_buf_s2m[ 1040 ] =  0x0
# updma_buf_s2m[ 1041 ] =  0x0
# updma_buf_s2m[ 1042 ] =  0x0
# updma_buf_s2m[ 1043 ] =  0x0
# updma_buf_s2m[ 1044 ] =  0x0
# updma_buf_s2m[ 1045 ] =  0x0
# updma_buf_s2m[ 1046 ] =  0x0
# updma_buf_s2m[ 1047 ] =  0x0
# updma_buf_s2m[ 1048 ] =  0x0
# updma_buf_s2m[ 1049 ] =  0x0
# updma_buf_s2m[ 1050 ] =  0x0
# updma_buf_s2m[ 1051 ] =  0x0
# updma_buf_s2m[ 1052 ] =  0x0
# updma_buf_s2m[ 1053 ] =  0x0
# updma_buf_s2m[ 1054 ] =  0x0
# updma_buf_s2m[ 1055 ] =  0x0
# updma_buf_s2m[ 1056 ] =  0x0
# updma_buf_s2m[ 1057 ] =  0x0
# updma_buf_s2m[ 1058 ] =  0x0
# updma_buf_s2m[ 1059 ] =  0x0
# updma_buf_s2m[ 1060 ] =  0x0
# updma_buf_s2m[ 1061 ] =  0x0
# updma_buf_s2m[ 1062 ] =  0x0
# updma_buf_s2m[ 1063 ] =  0x0
# updma_buf_s2m[ 1064 ] =  0x0
# updma_buf_s2m[ 1065 ] =  0x0
# updma_buf_s2m[ 1066 ] =  0x0
# updma_buf_s2m[ 1067 ] =  0x0
# updma_buf_s2m[ 1068 ] =  0x0
# updma_buf_s2m[ 1069 ] =  0x0
# updma_buf_s2m[ 1070 ] =  0x0
# updma_buf_s2m[ 1071 ] =  0x0
# updma_buf_s2m[ 1072 ] =  0x0
# updma_buf_s2m[ 1073 ] =  0x0
# updma_buf_s2m[ 1074 ] =  0x0
# updma_buf_s2m[ 1075 ] =  0x0
# updma_buf_s2m[ 1076 ] =  0x0
# updma_buf_s2m[ 1077 ] =  0x0
# updma_buf_s2m[ 1078 ] =  0x0
# updma_buf_s2m[ 1079 ] =  0x0
# updma_buf_s2m[ 1080 ] =  0x0
# updma_buf_s2m[ 1081 ] =  0x0
# updma_buf_s2m[ 1082 ] =  0x0
# updma_buf_s2m[ 1083 ] =  0x0
# updma_buf_s2m[ 1084 ] =  0x0
# updma_buf_s2m[ 1085 ] =  0x0
# updma_buf_s2m[ 1086 ] =  0x0
# updma_buf_s2m[ 1087 ] =  0x0
# updma_buf_s2m[ 1088 ] =  0x0
# updma_buf_s2m[ 1089 ] =  0x0
# updma_buf_s2m[ 1090 ] =  0x0
# updma_buf_s2m[ 1091 ] =  0x0
# updma_buf_s2m[ 1092 ] =  0x0
# updma_buf_s2m[ 1093 ] =  0x0
# updma_buf_s2m[ 1094 ] =  0x0
# updma_buf_s2m[ 1095 ] =  0x0
# updma_buf_s2m[ 1096 ] =  0x0
# updma_buf_s2m[ 1097 ] =  0x0
# updma_buf_s2m[ 1098 ] =  0x0
# updma_buf_s2m[ 1099 ] =  0x0
# updma_buf_s2m[ 1100 ] =  0x0
# updma_buf_s2m[ 1101 ] =  0x0
# updma_buf_s2m[ 1102 ] =  0x0
# updma_buf_s2m[ 1103 ] =  0x0
# updma_buf_s2m[ 1104 ] =  0x0
# updma_buf_s2m[ 1105 ] =  0x0
# updma_buf_s2m[ 1106 ] =  0x0
# updma_buf_s2m[ 1107 ] =  0x0
# updma_buf_s2m[ 1108 ] =  0x0
# updma_buf_s2m[ 1109 ] =  0x0
# updma_buf_s2m[ 1110 ] =  0x0
# updma_buf_s2m[ 1111 ] =  0x0
# updma_buf_s2m[ 1112 ] =  0x0
# updma_buf_s2m[ 1113 ] =  0x0
# updma_buf_s2m[ 1114 ] =  0x0
# updma_buf_s2m[ 1115 ] =  0x0
# updma_buf_s2m[ 1116 ] =  0x0
# updma_buf_s2m[ 1117 ] =  0x0
# updma_buf_s2m[ 1118 ] =  0x0
# updma_buf_s2m[ 1119 ] =  0x0
# updma_buf_s2m[ 1120 ] =  0x0
# updma_buf_s2m[ 1121 ] =  0x0
# updma_buf_s2m[ 1122 ] =  0x0
# updma_buf_s2m[ 1123 ] =  0x0
# updma_buf_s2m[ 1124 ] =  0x0
# updma_buf_s2m[ 1125 ] =  0x0
# updma_buf_s2m[ 1126 ] =  0x0
# updma_buf_s2m[ 1127 ] =  0x0
# updma_buf_s2m[ 1128 ] =  0x0
# updma_buf_s2m[ 1129 ] =  0x0
# updma_buf_s2m[ 1130 ] =  0x0
# updma_buf_s2m[ 1131 ] =  0x0
# updma_buf_s2m[ 1132 ] =  0x0
# updma_buf_s2m[ 1133 ] =  0x0
# updma_buf_s2m[ 1134 ] =  0x0
# updma_buf_s2m[ 1135 ] =  0x0
# updma_buf_s2m[ 1136 ] =  0x0
# updma_buf_s2m[ 1137 ] =  0x0
# updma_buf_s2m[ 1138 ] =  0x0
# updma_buf_s2m[ 1139 ] =  0x0
# updma_buf_s2m[ 1140 ] =  0x0
# updma_buf_s2m[ 1141 ] =  0x0
# updma_buf_s2m[ 1142 ] =  0x0
# updma_buf_s2m[ 1143 ] =  0x0
# updma_buf_s2m[ 1144 ] =  0x0
# updma_buf_s2m[ 1145 ] =  0x0
# updma_buf_s2m[ 1146 ] =  0x0
# updma_buf_s2m[ 1147 ] =  0x0
# updma_buf_s2m[ 1148 ] =  0x0
# updma_buf_s2m[ 1149 ] =  0x0
# updma_buf_s2m[ 1150 ] =  0x0
# updma_buf_s2m[ 1151 ] =  0x0
# updma_buf_s2m[ 1152 ] =  0x0
# updma_buf_s2m[ 1153 ] =  0x0
# updma_buf_s2m[ 1154 ] =  0x0
# updma_buf_s2m[ 1155 ] =  0x0
# updma_buf_s2m[ 1156 ] =  0x0
# updma_buf_s2m[ 1157 ] =  0x0
# updma_buf_s2m[ 1158 ] =  0x0
# updma_buf_s2m[ 1159 ] =  0x0
# updma_buf_s2m[ 1160 ] =  0x0
# updma_buf_s2m[ 1161 ] =  0x0
# updma_buf_s2m[ 1162 ] =  0x0
# updma_buf_s2m[ 1163 ] =  0x0
# updma_buf_s2m[ 1164 ] =  0x0
# updma_buf_s2m[ 1165 ] =  0x0
# updma_buf_s2m[ 1166 ] =  0x0
# updma_buf_s2m[ 1167 ] =  0x0
# updma_buf_s2m[ 1168 ] =  0x0
# updma_buf_s2m[ 1169 ] =  0x0
# updma_buf_s2m[ 1170 ] =  0x0
# updma_buf_s2m[ 1171 ] =  0x0
# updma_buf_s2m[ 1172 ] =  0x0
# updma_buf_s2m[ 1173 ] =  0x0
# updma_buf_s2m[ 1174 ] =  0x0
# updma_buf_s2m[ 1175 ] =  0x0
# updma_buf_s2m[ 1176 ] =  0x0
# updma_buf_s2m[ 1177 ] =  0x0
# updma_buf_s2m[ 1178 ] =  0x0
# updma_buf_s2m[ 1179 ] =  0x0
# updma_buf_s2m[ 1180 ] =  0x0
# updma_buf_s2m[ 1181 ] =  0x0
# updma_buf_s2m[ 1182 ] =  0x0
# updma_buf_s2m[ 1183 ] =  0x0
# updma_buf_s2m[ 1184 ] =  0x0
# updma_buf_s2m[ 1185 ] =  0x0
# updma_buf_s2m[ 1186 ] =  0x0
# updma_buf_s2m[ 1187 ] =  0x0
# updma_buf_s2m[ 1188 ] =  0x0
# updma_buf_s2m[ 1189 ] =  0x0
# updma_buf_s2m[ 1190 ] =  0x0
# updma_buf_s2m[ 1191 ] =  0x0
# updma_buf_s2m[ 1192 ] =  0x0
# updma_buf_s2m[ 1193 ] =  0x0
# updma_buf_s2m[ 1194 ] =  0x0
# updma_buf_s2m[ 1195 ] =  0x0
# updma_buf_s2m[ 1196 ] =  0x0
# updma_buf_s2m[ 1197 ] =  0x0
# updma_buf_s2m[ 1198 ] =  0x0
# updma_buf_s2m[ 1199 ] =  0x0
# updma_buf_s2m[ 1200 ] =  0x0
# updma_buf_s2m[ 1201 ] =  0x0
# updma_buf_s2m[ 1202 ] =  0x0
# updma_buf_s2m[ 1203 ] =  0x0
# updma_buf_s2m[ 1204 ] =  0x0
# updma_buf_s2m[ 1205 ] =  0x0
# updma_buf_s2m[ 1206 ] =  0x0
# updma_buf_s2m[ 1207 ] =  0x0
# updma_buf_s2m[ 1208 ] =  0x0
# updma_buf_s2m[ 1209 ] =  0x0
# updma_buf_s2m[ 1210 ] =  0x0
# updma_buf_s2m[ 1211 ] =  0x0
# updma_buf_s2m[ 1212 ] =  0x0
# updma_buf_s2m[ 1213 ] =  0x0
# updma_buf_s2m[ 1214 ] =  0x0
# updma_buf_s2m[ 1215 ] =  0x0
# updma_buf_s2m[ 1216 ] =  0x0
# updma_buf_s2m[ 1217 ] =  0x0
# updma_buf_s2m[ 1218 ] =  0x0
# updma_buf_s2m[ 1219 ] =  0x0
# updma_buf_s2m[ 1220 ] =  0x0
# updma_buf_s2m[ 1221 ] =  0x0
# updma_buf_s2m[ 1222 ] =  0x0
# updma_buf_s2m[ 1223 ] =  0x0
# updma_buf_s2m[ 1224 ] =  0x0
# updma_buf_s2m[ 1225 ] =  0x0
# updma_buf_s2m[ 1226 ] =  0x0
# updma_buf_s2m[ 1227 ] =  0x0
# updma_buf_s2m[ 1228 ] =  0x0
# updma_buf_s2m[ 1229 ] =  0x0
# updma_buf_s2m[ 1230 ] =  0x0
# updma_buf_s2m[ 1231 ] =  0x0
# updma_buf_s2m[ 1232 ] =  0x0
# updma_buf_s2m[ 1233 ] =  0x0
# updma_buf_s2m[ 1234 ] =  0x0
# updma_buf_s2m[ 1235 ] =  0x0
# updma_buf_s2m[ 1236 ] =  0x0
# updma_buf_s2m[ 1237 ] =  0x0
# updma_buf_s2m[ 1238 ] =  0x0
# updma_buf_s2m[ 1239 ] =  0x0
# updma_buf_s2m[ 1240 ] =  0x0
# updma_buf_s2m[ 1241 ] =  0x0
# updma_buf_s2m[ 1242 ] =  0x0
# updma_buf_s2m[ 1243 ] =  0x0
# updma_buf_s2m[ 1244 ] =  0x0
# updma_buf_s2m[ 1245 ] =  0x0
# updma_buf_s2m[ 1246 ] =  0x0
# updma_buf_s2m[ 1247 ] =  0x0
# updma_buf_s2m[ 1248 ] =  0x0
# updma_buf_s2m[ 1249 ] =  0x0
# updma_buf_s2m[ 1250 ] =  0x0
# updma_buf_s2m[ 1251 ] =  0x0
# updma_buf_s2m[ 1252 ] =  0x0
# updma_buf_s2m[ 1253 ] =  0x0
# updma_buf_s2m[ 1254 ] =  0x0
# updma_buf_s2m[ 1255 ] =  0x0
# updma_buf_s2m[ 1256 ] =  0x0
# updma_buf_s2m[ 1257 ] =  0x0
# updma_buf_s2m[ 1258 ] =  0x0
# updma_buf_s2m[ 1259 ] =  0x0
# updma_buf_s2m[ 1260 ] =  0x0
# updma_buf_s2m[ 1261 ] =  0x0
# updma_buf_s2m[ 1262 ] =  0x0
# updma_buf_s2m[ 1263 ] =  0x0
# updma_buf_s2m[ 1264 ] =  0x0
# updma_buf_s2m[ 1265 ] =  0x0
# updma_buf_s2m[ 1266 ] =  0x0
# updma_buf_s2m[ 1267 ] =  0x0
# updma_buf_s2m[ 1268 ] =  0x0
# updma_buf_s2m[ 1269 ] =  0x0
# updma_buf_s2m[ 1270 ] =  0x0
# updma_buf_s2m[ 1271 ] =  0x0
# updma_buf_s2m[ 1272 ] =  0x0
# updma_buf_s2m[ 1273 ] =  0x0
# updma_buf_s2m[ 1274 ] =  0x0
# updma_buf_s2m[ 1275 ] =  0x0
# updma_buf_s2m[ 1276 ] =  0x0
# updma_buf_s2m[ 1277 ] =  0x0
# updma_buf_s2m[ 1278 ] =  0x0
# updma_buf_s2m[ 1279 ] =  0x0
# updma_buf_s2m[ 1280 ] =  0x0
# updma_buf_s2m[ 1281 ] =  0x0
# updma_buf_s2m[ 1282 ] =  0x0
# updma_buf_s2m[ 1283 ] =  0x0
# updma_buf_s2m[ 1284 ] =  0x0
# updma_buf_s2m[ 1285 ] =  0x0
# updma_buf_s2m[ 1286 ] =  0x0
# updma_buf_s2m[ 1287 ] =  0x0
# updma_buf_s2m[ 1288 ] =  0x0
# updma_buf_s2m[ 1289 ] =  0x0
# updma_buf_s2m[ 1290 ] =  0x0
# updma_buf_s2m[ 1291 ] =  0x0
# updma_buf_s2m[ 1292 ] =  0x0
# updma_buf_s2m[ 1293 ] =  0x0
# updma_buf_s2m[ 1294 ] =  0x0
# updma_buf_s2m[ 1295 ] =  0x0
# updma_buf_s2m[ 1296 ] =  0x0
# updma_buf_s2m[ 1297 ] =  0x0
# updma_buf_s2m[ 1298 ] =  0x0
# updma_buf_s2m[ 1299 ] =  0x0
# updma_buf_s2m[ 1300 ] =  0x0
# updma_buf_s2m[ 1301 ] =  0x0
# updma_buf_s2m[ 1302 ] =  0x0
# updma_buf_s2m[ 1303 ] =  0x0
# updma_buf_s2m[ 1304 ] =  0x0
# updma_buf_s2m[ 1305 ] =  0x0
# updma_buf_s2m[ 1306 ] =  0x0
# updma_buf_s2m[ 1307 ] =  0x0
# updma_buf_s2m[ 1308 ] =  0x0
# updma_buf_s2m[ 1309 ] =  0x0
# updma_buf_s2m[ 1310 ] =  0x0
# updma_buf_s2m[ 1311 ] =  0x0
# updma_buf_s2m[ 1312 ] =  0x0
# updma_buf_s2m[ 1313 ] =  0x0
# updma_buf_s2m[ 1314 ] =  0x0
# updma_buf_s2m[ 1315 ] =  0x0
# updma_buf_s2m[ 1316 ] =  0x0
# updma_buf_s2m[ 1317 ] =  0x0
# updma_buf_s2m[ 1318 ] =  0x0
# updma_buf_s2m[ 1319 ] =  0x0
# updma_buf_s2m[ 1320 ] =  0x0
# updma_buf_s2m[ 1321 ] =  0x0
# updma_buf_s2m[ 1322 ] =  0x0
# updma_buf_s2m[ 1323 ] =  0x0
# updma_buf_s2m[ 1324 ] =  0x0
# updma_buf_s2m[ 1325 ] =  0x0
# updma_buf_s2m[ 1326 ] =  0x0
# updma_buf_s2m[ 1327 ] =  0x0
# updma_buf_s2m[ 1328 ] =  0x0
# updma_buf_s2m[ 1329 ] =  0x0
# updma_buf_s2m[ 1330 ] =  0x0
# updma_buf_s2m[ 1331 ] =  0x0
# updma_buf_s2m[ 1332 ] =  0x0
# updma_buf_s2m[ 1333 ] =  0x0
# updma_buf_s2m[ 1334 ] =  0x0
# updma_buf_s2m[ 1335 ] =  0x0
# updma_buf_s2m[ 1336 ] =  0x0
# updma_buf_s2m[ 1337 ] =  0x0
# updma_buf_s2m[ 1338 ] =  0x0
# updma_buf_s2m[ 1339 ] =  0x0
# updma_buf_s2m[ 1340 ] =  0x0
# updma_buf_s2m[ 1341 ] =  0x0
# updma_buf_s2m[ 1342 ] =  0x0
# updma_buf_s2m[ 1343 ] =  0x0
# updma_buf_s2m[ 1344 ] =  0x0
# updma_buf_s2m[ 1345 ] =  0x0
# updma_buf_s2m[ 1346 ] =  0x0
# updma_buf_s2m[ 1347 ] =  0x0
# updma_buf_s2m[ 1348 ] =  0x0
# updma_buf_s2m[ 1349 ] =  0x0
# updma_buf_s2m[ 1350 ] =  0x0
# updma_buf_s2m[ 1351 ] =  0x0
# updma_buf_s2m[ 1352 ] =  0x0
# updma_buf_s2m[ 1353 ] =  0x0
# updma_buf_s2m[ 1354 ] =  0x0
# updma_buf_s2m[ 1355 ] =  0x0
# updma_buf_s2m[ 1356 ] =  0x0
# updma_buf_s2m[ 1357 ] =  0x0
# updma_buf_s2m[ 1358 ] =  0x0
# updma_buf_s2m[ 1359 ] =  0x0
# updma_buf_s2m[ 1360 ] =  0x0
# updma_buf_s2m[ 1361 ] =  0x0
# updma_buf_s2m[ 1362 ] =  0x0
# updma_buf_s2m[ 1363 ] =  0x0
# updma_buf_s2m[ 1364 ] =  0x0
# updma_buf_s2m[ 1365 ] =  0x0
# updma_buf_s2m[ 1366 ] =  0x0
# updma_buf_s2m[ 1367 ] =  0x0
# updma_buf_s2m[ 1368 ] =  0x0
# updma_buf_s2m[ 1369 ] =  0x0
# updma_buf_s2m[ 1370 ] =  0x0
# updma_buf_s2m[ 1371 ] =  0x0
# updma_buf_s2m[ 1372 ] =  0x0
# updma_buf_s2m[ 1373 ] =  0x0
# updma_buf_s2m[ 1374 ] =  0x0
# updma_buf_s2m[ 1375 ] =  0x0
# updma_buf_s2m[ 1376 ] =  0x0
# updma_buf_s2m[ 1377 ] =  0x0
# updma_buf_s2m[ 1378 ] =  0x0
# updma_buf_s2m[ 1379 ] =  0x0
# updma_buf_s2m[ 1380 ] =  0x0
# updma_buf_s2m[ 1381 ] =  0x0
# updma_buf_s2m[ 1382 ] =  0x0
# updma_buf_s2m[ 1383 ] =  0x0
# updma_buf_s2m[ 1384 ] =  0x0
# updma_buf_s2m[ 1385 ] =  0x0
# updma_buf_s2m[ 1386 ] =  0x0
# updma_buf_s2m[ 1387 ] =  0x0
# updma_buf_s2m[ 1388 ] =  0x0
# updma_buf_s2m[ 1389 ] =  0x0
# updma_buf_s2m[ 1390 ] =  0x0
# updma_buf_s2m[ 1391 ] =  0x0
# updma_buf_s2m[ 1392 ] =  0x0
# updma_buf_s2m[ 1393 ] =  0x0
# updma_buf_s2m[ 1394 ] =  0x0
# updma_buf_s2m[ 1395 ] =  0x0
# updma_buf_s2m[ 1396 ] =  0x0
# updma_buf_s2m[ 1397 ] =  0x0
# updma_buf_s2m[ 1398 ] =  0x0
# updma_buf_s2m[ 1399 ] =  0x0
# updma_buf_s2m[ 1400 ] =  0x0
# updma_buf_s2m[ 1401 ] =  0x0
# updma_buf_s2m[ 1402 ] =  0x0
# updma_buf_s2m[ 1403 ] =  0x0
# updma_buf_s2m[ 1404 ] =  0x0
# updma_buf_s2m[ 1405 ] =  0x0
# updma_buf_s2m[ 1406 ] =  0x0
# updma_buf_s2m[ 1407 ] =  0x0
# updma_buf_s2m[ 1408 ] =  0x0
# updma_buf_s2m[ 1409 ] =  0x0
# updma_buf_s2m[ 1410 ] =  0x0
# updma_buf_s2m[ 1411 ] =  0x0
# updma_buf_s2m[ 1412 ] =  0x0
# updma_buf_s2m[ 1413 ] =  0x0
# updma_buf_s2m[ 1414 ] =  0x0
# updma_buf_s2m[ 1415 ] =  0x0
# updma_buf_s2m[ 1416 ] =  0x0
# updma_buf_s2m[ 1417 ] =  0x0
# updma_buf_s2m[ 1418 ] =  0x0
# updma_buf_s2m[ 1419 ] =  0x0
# updma_buf_s2m[ 1420 ] =  0x0
# updma_buf_s2m[ 1421 ] =  0x0
# updma_buf_s2m[ 1422 ] =  0x0
# updma_buf_s2m[ 1423 ] =  0x0
# updma_buf_s2m[ 1424 ] =  0x0
# updma_buf_s2m[ 1425 ] =  0x0
# updma_buf_s2m[ 1426 ] =  0x0
# updma_buf_s2m[ 1427 ] =  0x0
# updma_buf_s2m[ 1428 ] =  0x0
# updma_buf_s2m[ 1429 ] =  0x0
# updma_buf_s2m[ 1430 ] =  0x0
# updma_buf_s2m[ 1431 ] =  0x0
# updma_buf_s2m[ 1432 ] =  0x0
# updma_buf_s2m[ 1433 ] =  0x0
# updma_buf_s2m[ 1434 ] =  0x0
# updma_buf_s2m[ 1435 ] =  0x0
# updma_buf_s2m[ 1436 ] =  0x0
# updma_buf_s2m[ 1437 ] =  0x0
# updma_buf_s2m[ 1438 ] =  0x0
# updma_buf_s2m[ 1439 ] =  0x0
# updma_buf_s2m[ 1440 ] =  0x0
# updma_buf_s2m[ 1441 ] =  0x0
# updma_buf_s2m[ 1442 ] =  0x0
# updma_buf_s2m[ 1443 ] =  0x0
# updma_buf_s2m[ 1444 ] =  0x0
# updma_buf_s2m[ 1445 ] =  0x0
# updma_buf_s2m[ 1446 ] =  0x0
# updma_buf_s2m[ 1447 ] =  0x0
# updma_buf_s2m[ 1448 ] =  0x0
# updma_buf_s2m[ 1449 ] =  0x0
# updma_buf_s2m[ 1450 ] =  0x0
# updma_buf_s2m[ 1451 ] =  0x0
# updma_buf_s2m[ 1452 ] =  0x0
# updma_buf_s2m[ 1453 ] =  0x0
# updma_buf_s2m[ 1454 ] =  0x0
# updma_buf_s2m[ 1455 ] =  0x0
# updma_buf_s2m[ 1456 ] =  0x0
# updma_buf_s2m[ 1457 ] =  0x0
# updma_buf_s2m[ 1458 ] =  0x0
# updma_buf_s2m[ 1459 ] =  0x0
# updma_buf_s2m[ 1460 ] =  0x0
# updma_buf_s2m[ 1461 ] =  0x0
# updma_buf_s2m[ 1462 ] =  0x0
# updma_buf_s2m[ 1463 ] =  0x0
# updma_buf_s2m[ 1464 ] =  0x0
# updma_buf_s2m[ 1465 ] =  0x0
# updma_buf_s2m[ 1466 ] =  0x0
# updma_buf_s2m[ 1467 ] =  0x0
# updma_buf_s2m[ 1468 ] =  0x0
# updma_buf_s2m[ 1469 ] =  0x0
# updma_buf_s2m[ 1470 ] =  0x0
# updma_buf_s2m[ 1471 ] =  0x0
# updma_buf_s2m[ 1472 ] =  0x0
# updma_buf_s2m[ 1473 ] =  0x0
# updma_buf_s2m[ 1474 ] =  0x0
# updma_buf_s2m[ 1475 ] =  0x0
# updma_buf_s2m[ 1476 ] =  0x0
# updma_buf_s2m[ 1477 ] =  0x0
# updma_buf_s2m[ 1478 ] =  0x0
# updma_buf_s2m[ 1479 ] =  0x0
# updma_buf_s2m[ 1480 ] =  0x0
# updma_buf_s2m[ 1481 ] =  0x0
# updma_buf_s2m[ 1482 ] =  0x0
# updma_buf_s2m[ 1483 ] =  0x0
# updma_buf_s2m[ 1484 ] =  0x0
# updma_buf_s2m[ 1485 ] =  0x0
# updma_buf_s2m[ 1486 ] =  0x0
# updma_buf_s2m[ 1487 ] =  0x0
# updma_buf_s2m[ 1488 ] =  0x0
# updma_buf_s2m[ 1489 ] =  0x0
# updma_buf_s2m[ 1490 ] =  0x0
# updma_buf_s2m[ 1491 ] =  0x0
# updma_buf_s2m[ 1492 ] =  0x0
# updma_buf_s2m[ 1493 ] =  0x0
# updma_buf_s2m[ 1494 ] =  0x0
# updma_buf_s2m[ 1495 ] =  0x0
# updma_buf_s2m[ 1496 ] =  0x0
# updma_buf_s2m[ 1497 ] =  0x0
# updma_buf_s2m[ 1498 ] =  0x0
# updma_buf_s2m[ 1499 ] =  0x0
# updma_buf_s2m[ 1500 ] =  0x0
# updma_buf_s2m[ 1501 ] =  0x0
# updma_buf_s2m[ 1502 ] =  0x0
# updma_buf_s2m[ 1503 ] =  0x0
# updma_buf_s2m[ 1504 ] =  0x0
# updma_buf_s2m[ 1505 ] =  0x0
# updma_buf_s2m[ 1506 ] =  0x0
# updma_buf_s2m[ 1507 ] =  0x0
# updma_buf_s2m[ 1508 ] =  0x0
# updma_buf_s2m[ 1509 ] =  0x0
# updma_buf_s2m[ 1510 ] =  0x0
# updma_buf_s2m[ 1511 ] =  0x0
# updma_buf_s2m[ 1512 ] =  0x0
# updma_buf_s2m[ 1513 ] =  0x0
# updma_buf_s2m[ 1514 ] =  0x0
# updma_buf_s2m[ 1515 ] =  0x0
# updma_buf_s2m[ 1516 ] =  0x0
# updma_buf_s2m[ 1517 ] =  0x0
# updma_buf_s2m[ 1518 ] =  0x0
# updma_buf_s2m[ 1519 ] =  0x0
# updma_buf_s2m[ 1520 ] =  0x0
# updma_buf_s2m[ 1521 ] =  0x0
# updma_buf_s2m[ 1522 ] =  0x0
# updma_buf_s2m[ 1523 ] =  0x0
# updma_buf_s2m[ 1524 ] =  0x0
# updma_buf_s2m[ 1525 ] =  0x0
# updma_buf_s2m[ 1526 ] =  0x0
# updma_buf_s2m[ 1527 ] =  0x0
# updma_buf_s2m[ 1528 ] =  0x0
# updma_buf_s2m[ 1529 ] =  0x0
# updma_buf_s2m[ 1530 ] =  0x0
# updma_buf_s2m[ 1531 ] =  0x0
# updma_buf_s2m[ 1532 ] =  0x0
# updma_buf_s2m[ 1533 ] =  0x0
# updma_buf_s2m[ 1534 ] =  0x0
# updma_buf_s2m[ 1535 ] =  0x0
# updma_buf_s2m[ 1536 ] =  0x0
# updma_buf_s2m[ 1537 ] =  0x0
# updma_buf_s2m[ 1538 ] =  0x0
# updma_buf_s2m[ 1539 ] =  0x0
# updma_buf_s2m[ 1540 ] =  0x0
# updma_buf_s2m[ 1541 ] =  0x0
# updma_buf_s2m[ 1542 ] =  0x0
# updma_buf_s2m[ 1543 ] =  0x0
# updma_buf_s2m[ 1544 ] =  0x0
# updma_buf_s2m[ 1545 ] =  0x0
# updma_buf_s2m[ 1546 ] =  0x0
# updma_buf_s2m[ 1547 ] =  0x0
# updma_buf_s2m[ 1548 ] =  0x0
# updma_buf_s2m[ 1549 ] =  0x0
# updma_buf_s2m[ 1550 ] =  0x0
# updma_buf_s2m[ 1551 ] =  0x0
# updma_buf_s2m[ 1552 ] =  0x0
# updma_buf_s2m[ 1553 ] =  0x0
# updma_buf_s2m[ 1554 ] =  0x0
# updma_buf_s2m[ 1555 ] =  0x0
# updma_buf_s2m[ 1556 ] =  0x0
# updma_buf_s2m[ 1557 ] =  0x0
# updma_buf_s2m[ 1558 ] =  0x0
# updma_buf_s2m[ 1559 ] =  0x0
# updma_buf_s2m[ 1560 ] =  0x0
# updma_buf_s2m[ 1561 ] =  0x0
# updma_buf_s2m[ 1562 ] =  0x0
# updma_buf_s2m[ 1563 ] =  0x0
# updma_buf_s2m[ 1564 ] =  0x0
# updma_buf_s2m[ 1565 ] =  0x0
# updma_buf_s2m[ 1566 ] =  0x0
# updma_buf_s2m[ 1567 ] =  0x0
# updma_buf_s2m[ 1568 ] =  0x0
# updma_buf_s2m[ 1569 ] =  0x0
# updma_buf_s2m[ 1570 ] =  0x0
# updma_buf_s2m[ 1571 ] =  0x0
# updma_buf_s2m[ 1572 ] =  0x0
# updma_buf_s2m[ 1573 ] =  0x0
# updma_buf_s2m[ 1574 ] =  0x0
# updma_buf_s2m[ 1575 ] =  0x0
# updma_buf_s2m[ 1576 ] =  0x0
# updma_buf_s2m[ 1577 ] =  0x0
# updma_buf_s2m[ 1578 ] =  0x0
# updma_buf_s2m[ 1579 ] =  0x0
# updma_buf_s2m[ 1580 ] =  0x0
# updma_buf_s2m[ 1581 ] =  0x0
# updma_buf_s2m[ 1582 ] =  0x0
# updma_buf_s2m[ 1583 ] =  0x0
# updma_buf_s2m[ 1584 ] =  0x0
# updma_buf_s2m[ 1585 ] =  0x0
# updma_buf_s2m[ 1586 ] =  0x0
# updma_buf_s2m[ 1587 ] =  0x0
# updma_buf_s2m[ 1588 ] =  0x0
# updma_buf_s2m[ 1589 ] =  0x0
# updma_buf_s2m[ 1590 ] =  0x0
# updma_buf_s2m[ 1591 ] =  0x0
# updma_buf_s2m[ 1592 ] =  0x0
# updma_buf_s2m[ 1593 ] =  0x0
# updma_buf_s2m[ 1594 ] =  0x0
# updma_buf_s2m[ 1595 ] =  0x0
# updma_buf_s2m[ 1596 ] =  0x0
# updma_buf_s2m[ 1597 ] =  0x0
# updma_buf_s2m[ 1598 ] =  0x0
# updma_buf_s2m[ 1599 ] =  0x0
# updma_buf_s2m[ 1600 ] =  0x0
# updma_buf_s2m[ 1601 ] =  0x0
# updma_buf_s2m[ 1602 ] =  0x0
# updma_buf_s2m[ 1603 ] =  0x0
# updma_buf_s2m[ 1604 ] =  0x0
# updma_buf_s2m[ 1605 ] =  0x0
# updma_buf_s2m[ 1606 ] =  0x0
# updma_buf_s2m[ 1607 ] =  0x0
# updma_buf_s2m[ 1608 ] =  0x0
# updma_buf_s2m[ 1609 ] =  0x0
# updma_buf_s2m[ 1610 ] =  0x0
# updma_buf_s2m[ 1611 ] =  0x0
# updma_buf_s2m[ 1612 ] =  0x0
# updma_buf_s2m[ 1613 ] =  0x0
# updma_buf_s2m[ 1614 ] =  0x0
# updma_buf_s2m[ 1615 ] =  0x0
# updma_buf_s2m[ 1616 ] =  0x0
# updma_buf_s2m[ 1617 ] =  0x0
# updma_buf_s2m[ 1618 ] =  0x0
# updma_buf_s2m[ 1619 ] =  0x0
# updma_buf_s2m[ 1620 ] =  0x0
# updma_buf_s2m[ 1621 ] =  0x0
# updma_buf_s2m[ 1622 ] =  0x0
# updma_buf_s2m[ 1623 ] =  0x0
# updma_buf_s2m[ 1624 ] =  0x0
# updma_buf_s2m[ 1625 ] =  0x0
# updma_buf_s2m[ 1626 ] =  0x0
# updma_buf_s2m[ 1627 ] =  0x0
# updma_buf_s2m[ 1628 ] =  0x0
# updma_buf_s2m[ 1629 ] =  0x0
# updma_buf_s2m[ 1630 ] =  0x0
# updma_buf_s2m[ 1631 ] =  0x0
# updma_buf_s2m[ 1632 ] =  0x0
# updma_buf_s2m[ 1633 ] =  0x0
# updma_buf_s2m[ 1634 ] =  0x0
# updma_buf_s2m[ 1635 ] =  0x0
# updma_buf_s2m[ 1636 ] =  0x0
# updma_buf_s2m[ 1637 ] =  0x0
# updma_buf_s2m[ 1638 ] =  0x0
# updma_buf_s2m[ 1639 ] =  0x0
# updma_buf_s2m[ 1640 ] =  0x0
# updma_buf_s2m[ 1641 ] =  0x0
# updma_buf_s2m[ 1642 ] =  0x0
# updma_buf_s2m[ 1643 ] =  0x0
# updma_buf_s2m[ 1644 ] =  0x0
# updma_buf_s2m[ 1645 ] =  0x0
# updma_buf_s2m[ 1646 ] =  0x0
# updma_buf_s2m[ 1647 ] =  0x0
# updma_buf_s2m[ 1648 ] =  0x0
# updma_buf_s2m[ 1649 ] =  0x0
# updma_buf_s2m[ 1650 ] =  0x0
# updma_buf_s2m[ 1651 ] =  0x0
# updma_buf_s2m[ 1652 ] =  0x0
# updma_buf_s2m[ 1653 ] =  0x0
# updma_buf_s2m[ 1654 ] =  0x0
# updma_buf_s2m[ 1655 ] =  0x0
# updma_buf_s2m[ 1656 ] =  0x0
# updma_buf_s2m[ 1657 ] =  0x0
# updma_buf_s2m[ 1658 ] =  0x0
# updma_buf_s2m[ 1659 ] =  0x0
# updma_buf_s2m[ 1660 ] =  0x0
# updma_buf_s2m[ 1661 ] =  0x0
# updma_buf_s2m[ 1662 ] =  0x0
# updma_buf_s2m[ 1663 ] =  0x0
# updma_buf_s2m[ 1664 ] =  0x0
# updma_buf_s2m[ 1665 ] =  0x0
# updma_buf_s2m[ 1666 ] =  0x0
# updma_buf_s2m[ 1667 ] =  0x0
# updma_buf_s2m[ 1668 ] =  0x0
# updma_buf_s2m[ 1669 ] =  0x0
# updma_buf_s2m[ 1670 ] =  0x0
# updma_buf_s2m[ 1671 ] =  0x0
# updma_buf_s2m[ 1672 ] =  0x0
# updma_buf_s2m[ 1673 ] =  0x0
# updma_buf_s2m[ 1674 ] =  0x0
# updma_buf_s2m[ 1675 ] =  0x0
# updma_buf_s2m[ 1676 ] =  0x0
# updma_buf_s2m[ 1677 ] =  0x0
# updma_buf_s2m[ 1678 ] =  0x0
# updma_buf_s2m[ 1679 ] =  0x0
# updma_buf_s2m[ 1680 ] =  0x0
# updma_buf_s2m[ 1681 ] =  0x0
# updma_buf_s2m[ 1682 ] =  0x0
# updma_buf_s2m[ 1683 ] =  0x0
# updma_buf_s2m[ 1684 ] =  0x0
# updma_buf_s2m[ 1685 ] =  0x0
# updma_buf_s2m[ 1686 ] =  0x0
# updma_buf_s2m[ 1687 ] =  0x0
# updma_buf_s2m[ 1688 ] =  0x0
# updma_buf_s2m[ 1689 ] =  0x0
# updma_buf_s2m[ 1690 ] =  0x0
# updma_buf_s2m[ 1691 ] =  0x0
# updma_buf_s2m[ 1692 ] =  0x0
# ...
# updma_buf_s2m[ 42934 ] =  0xb1b62846
# updma_buf_s2m[ 42935 ] =  0xef09d03c
# updma_buf_s2m[ 42936 ] =  0x5457458c
# updma_buf_s2m[ 42937 ] =  0xc3d1920c
# updma_buf_s2m[ 42938 ] =  0xf379a7ab
# updma_buf_s2m[ 42939 ] =  0x51afd2d6
# updma_buf_s2m[ 42940 ] =  0xed46c2e9
# updma_buf_s2m[ 42941 ] =  0xfadb1669
# updma_buf_s2m[ 42942 ] =  0x509a9d3c
# updma_buf_s2m[ 42943 ] =  0xe7d49338
# updma_buf_s2m[ 42944 ] =  0xfa960cca
# updma_buf_s2m[ 42945 ] =  0x742044b9
# updma_buf_s2m[ 42946 ] =  0xc731b1c7
# updma_buf_s2m[ 42947 ] =  0xf9711f1b
# updma_buf_s2m[ 42948 ] =  0x610fcb24
# updma_buf_s2m[ 42949 ] =  0xc53b7ff6
# updma_buf_s2m[ 42950 ] =  0xfcacfbc1
# updma_buf_s2m[ 42951 ] =  0x7da73900
# updma_buf_s2m[ 42952 ] =  0xa7204331
# updma_buf_s2m[ 42953 ] =  0xff9dcc0b
# updma_buf_s2m[ 42954 ] =  0x749ec6ea
# updma_buf_s2m[ 42955 ] =  0xb89fc85a
# updma_buf_s2m[ 42956 ] =  0xf9c99132
# updma_buf_s2m[ 42957 ] =  0x4a5b2c51
# updma_buf_s2m[ 42958 ] =  0xd98813bd
# updma_buf_s2m[ 42959 ] =  0xf7eff891
# updma_buf_s2m[ 42960 ] =  0x6752531a
# updma_buf_s2m[ 42961 ] =  0xc6f24595
# updma_buf_s2m[ 42962 ] =  0x3fb89c8
# updma_buf_s2m[ 42963 ] =  0x42e44914
# updma_buf_s2m[ 42964 ] =  0xd2c85ed9
# updma_buf_s2m[ 42965 ] =  0x15559ed5
# updma_buf_s2m[ 42966 ] =  0x77917a4c
# updma_buf_s2m[ 42967 ] =  0x9f726aa9
# updma_buf_s2m[ 42968 ] =  0x384d5841
# updma_buf_s2m[ 42969 ] =  0x4a88da12
# updma_buf_s2m[ 42970 ] =  0xd10affe7
# updma_buf_s2m[ 42971 ] =  0xd41cfcd7
# updma_buf_s2m[ 42972 ] =  0x50973cc4
# updma_buf_s2m[ 42973 ] =  0xd47ee4fb
# updma_buf_s2m[ 42974 ] =  0x8b8f8e88
# updma_buf_s2m[ 42975 ] =  0x2c929faf
# updma_buf_s2m[ 42976 ] =  0xe38a3943
# updma_buf_s2m[ 42977 ] =  0xb61f3edd
# updma_buf_s2m[ 42978 ] =  0x4597a146
# updma_buf_s2m[ 42979 ] =  0xcc533756
# updma_buf_s2m[ 42980 ] =  0xa5537ead
# updma_buf_s2m[ 42981 ] =  0x42779116
# updma_buf_s2m[ 42982 ] =  0xd9db7dd6
# updma_buf_s2m[ 42983 ] =  0xea116cb1
# updma_buf_s2m[ 42984 ] =  0x4f2e6a73
# updma_buf_s2m[ 42985 ] =  0xd5813f1f
# updma_buf_s2m[ 42986 ] =  0xef76496d
# updma_buf_s2m[ 42987 ] =  0x6f6f317f
# updma_buf_s2m[ 42988 ] =  0xbc47ecdf
# updma_buf_s2m[ 42989 ] =  0xdf5f5073
# updma_buf_s2m[ 42990 ] =  0x465ea368
# updma_buf_s2m[ 42991 ] =  0xe0464195
# updma_buf_s2m[ 42992 ] =  0xec55b601
# updma_buf_s2m[ 42993 ] =  0x61748e8b
# updma_buf_s2m[ 42994 ] =  0xd56ec5ed
# updma_buf_s2m[ 42995 ] =  0xe498dc6f
# updma_buf_s2m[ 42996 ] =  0x5c565133
# updma_buf_s2m[ 42997 ] =  0xd5bd4119
# updma_buf_s2m[ 42998 ] =  0xe43ea340
# updma_buf_s2m[ 42999 ] =  0x6234cba8
# updma_buf_s2m[ 43000 ] =  0xd2b7c2f6
# updma_buf_s2m[ 43001 ] =  0xdc728a0b
# updma_buf_s2m[ 43002 ] =  0x0
# updma_buf_s2m[ 43003 ] =  0x0
# updma_buf_s2m[ 43004 ] =  0x0
# updma_buf_s2m[ 43005 ] =  0x0
# updma_buf_s2m[ 43006 ] =  0x0
# updma_buf_s2m[ 43007 ] =  0x0
# updma_buf_s2m[ 43008 ] =  0x0
# updma_buf_s2m[ 43009 ] =  0x0
# updma_buf_s2m[ 43010 ] =  0x0
# updma_buf_s2m[ 43011 ] =  0x0
# updma_buf_s2m[ 43012 ] =  0x0
# updma_buf_s2m[ 43013 ] =  0x0
# updma_buf_s2m[ 43014 ] =  0x2bf360e7
# updma_buf_s2m[ 43015 ] =  0xaf7885cf
# updma_buf_s2m[ 43016 ] =  0xff95fab1
# updma_buf_s2m[ 43017 ] =  0x36187874
# updma_buf_s2m[ 43018 ] =  0x9b9b929c
# updma_buf_s2m[ 43019 ] =  0xfdb99d14
# updma_buf_s2m[ 43020 ] =  0x25e45675
# updma_buf_s2m[ 43021 ] =  0xbb528948
# updma_buf_s2m[ 43022 ] =  0xfcf9537a
# updma_buf_s2m[ 43023 ] =  0x28a52693
# updma_buf_s2m[ 43024 ] =  0xa4615c63
# updma_buf_s2m[ 43025 ] =  0xfc0e0604
# updma_buf_s2m[ 43026 ] =  0x65de81dd
# updma_buf_s2m[ 43027 ] =  0xb6d48d9
# updma_buf_s2m[ 43028 ] =  0xe89b49d5
# updma_buf_s2m[ 43029 ] =  0x5320c4f7
# updma_buf_s2m[ 43030 ] =  0xef8ff671
# updma_buf_s2m[ 43031 ] =  0xedde88f5
# updma_buf_s2m[ 43032 ] =  0x5577c8e0
# updma_buf_s2m[ 43033 ] =  0xd5d4dfe9
# updma_buf_s2m[ 43034 ] =  0xef2a1de3
# updma_buf_s2m[ 43035 ] =  0x635f5864
# updma_buf_s2m[ 43036 ] =  0xb1c98d51
# updma_buf_s2m[ 43037 ] =  0xf63ed941
# updma_buf_s2m[ 43038 ] =  0x455b9e67
# updma_buf_s2m[ 43039 ] =  0xb7723bb4
# updma_buf_s2m[ 43040 ] =  0x4e1b4b5
# updma_buf_s2m[ 43041 ] =  0x56fa0e55
# updma_buf_s2m[ 43042 ] =  0xa835d5d0
# updma_buf_s2m[ 43043 ] =  0xfdd122f7
# updma_buf_s2m[ 43044 ] =  0x492dc17a
# updma_buf_s2m[ 43045 ] =  0xb9e1f036
# updma_buf_s2m[ 43046 ] =  0xf8b68a04
# updma_buf_s2m[ 43047 ] =  0x651548ae
# updma_buf_s2m[ 43048 ] =  0xa7e9e9cb
# updma_buf_s2m[ 43049 ] =  0xefacd457
# updma_buf_s2m[ 43050 ] =  0x40fbfae1
# updma_buf_s2m[ 43051 ] =  0xccaef9b5
# updma_buf_s2m[ 43052 ] =  0xf29a6d7e
# updma_buf_s2m[ 43053 ] =  0x4ebb8cb9
# updma_buf_s2m[ 43054 ] =  0xc47e9ed9
# updma_buf_s2m[ 43055 ] =  0xedc52d5a
# updma_buf_s2m[ 43056 ] =  0x55d7e447
# updma_buf_s2m[ 43057 ] =  0xbec53398
# updma_buf_s2m[ 43058 ] =  0xeae087c0
# updma_buf_s2m[ 43059 ] =  0x50eae736
# updma_buf_s2m[ 43060 ] =  0xbe3b484b
# updma_buf_s2m[ 43061 ] =  0xeadbc05e
# updma_buf_s2m[ 43062 ] =  0x7e58da05
# updma_buf_s2m[ 43063 ] =  0x8a2beabe
# updma_buf_s2m[ 43064 ] =  0xdc3cb1f3
# updma_buf_s2m[ 43065 ] =  0x56f96e38
# updma_buf_s2m[ 43066 ] =  0xa3951fea
# updma_buf_s2m[ 43067 ] =  0xe2cb90c6
# updma_buf_s2m[ 43068 ] =  0x46218f19
# updma_buf_s2m[ 43069 ] =  0xaf505227
# updma_buf_s2m[ 43070 ] =  0xe566b0e0
# updma_buf_s2m[ 43071 ] =  0x2c70485e
# updma_buf_s2m[ 43072 ] =  0xaf203319
# updma_buf_s2m[ 43073 ] =  0xe6a35749
# updma_buf_s2m[ 43074 ] =  0x75fc7fcf
# updma_buf_s2m[ 43075 ] =  0xee4f9f5b
# updma_buf_s2m[ 43076 ] =  0x77d5df1
# updma_buf_s2m[ 43077 ] =  0x401e79c7
# updma_buf_s2m[ 43078 ] =  0xf3da1c11
# updma_buf_s2m[ 43079 ] =  0x508d83a
# updma_buf_s2m[ 43080 ] =  0x7733eecb
# updma_buf_s2m[ 43081 ] =  0xb5f21891
# updma_buf_s2m[ 43082 ] =  0xf6db4217
# updma_buf_s2m[ 43083 ] =  0x489f4343
# updma_buf_s2m[ 43084 ] =  0xbc598093
# updma_buf_s2m[ 43085 ] =  0xf1fc8184
# updma_buf_s2m[ 43086 ] =  0x734a91b1
# updma_buf_s2m[ 43087 ] =  0xfbc0284d
# updma_buf_s2m[ 43088 ] =  0x94a550f
# updma_buf_s2m[ 43089 ] =  0x4787689f
# updma_buf_s2m[ 43090 ] =  0x9b407e80
# updma_buf_s2m[ 43091 ] =  0xe5007969
# updma_buf_s2m[ 43092 ] =  0x47c39360
# updma_buf_s2m[ 43093 ] =  0xb36e1f73
# updma_buf_s2m[ 43094 ] =  0xec99ed9d
# updma_buf_s2m[ 43095 ] =  0x697bf576
# updma_buf_s2m[ 43096 ] =  0x98a03241
# updma_buf_s2m[ 43097 ] =  0xe6867c8e
# updma_buf_s2m[ 43098 ] =  0x5941dd37
# updma_buf_s2m[ 43099 ] =  0xd7a8c218
# updma_buf_s2m[ 43100 ] =  0xfb7c07aa
# updma_buf_s2m[ 43101 ] =  0x595a7a55
# updma_buf_s2m[ 43102 ] =  0xcb34fbcb
# updma_buf_s2m[ 43103 ] =  0xf7ba6417
# updma_buf_s2m[ 43104 ] =  0x769499ea
# updma_buf_s2m[ 43105 ] =  0xab430043
# updma_buf_s2m[ 43106 ] =  0xf06e6928
# updma_buf_s2m[ 43107 ] =  0x78ed87fb
# updma_buf_s2m[ 43108 ] =  0x987b9aba
# updma_buf_s2m[ 43109 ] =  0xe92d1ad0
# updma_buf_s2m[ 43110 ] =  0x46e481c1
# updma_buf_s2m[ 43111 ] =  0xb8c35bea
# updma_buf_s2m[ 43112 ] =  0xefa004b3
# updma_buf_s2m[ 43113 ] =  0x4a6d48db
# updma_buf_s2m[ 43114 ] =  0xb4de303f
# updma_buf_s2m[ 43115 ] =  0xf17a6ccf
# updma_buf_s2m[ 43116 ] =  0x5cd2df58
# updma_buf_s2m[ 43117 ] =  0x9d32bfa4
# updma_buf_s2m[ 43118 ] =  0xed455c50
# updma_buf_s2m[ 43119 ] =  0x41a59beb
# updma_buf_s2m[ 43120 ] =  0xc4421e1d
# updma_buf_s2m[ 43121 ] =  0xf5232d01
# updma_buf_s2m[ 43122 ] =  0x5489998b
# updma_buf_s2m[ 43123 ] =  0xb434ed0a
# updma_buf_s2m[ 43124 ] =  0xef8e049a
# updma_buf_s2m[ 43125 ] =  0x4064eea3
# updma_buf_s2m[ 43126 ] =  0xca6cc55d
# updma_buf_s2m[ 43127 ] =  0xf2736e8b
# updma_buf_s2m[ 43128 ] =  0x4f629cf0
# updma_buf_s2m[ 43129 ] =  0xcefc8e41
# updma_buf_s2m[ 43130 ] =  0xeff648aa
# updma_buf_s2m[ 43131 ] =  0x7b67d787
# updma_buf_s2m[ 43132 ] =  0xbdc29dd9
# updma_buf_s2m[ 43133 ] =  0xe6d1af12
# updma_buf_s2m[ 43134 ] =  0x59f26f2e
# updma_buf_s2m[ 43135 ] =  0xc40e307a
# updma_buf_s2m[ 43136 ] =  0xec65da3d
# updma_buf_s2m[ 43137 ] =  0x5464d189
# updma_buf_s2m[ 43138 ] =  0xc412eb3f
# updma_buf_s2m[ 43139 ] =  0xed638ee9
# updma_buf_s2m[ 43140 ] =  0x74d77c98
# updma_buf_s2m[ 43141 ] =  0xa3205d4a
# updma_buf_s2m[ 43142 ] =  0xe562a01b
# updma_buf_s2m[ 43143 ] =  0x6dcbebcb
# updma_buf_s2m[ 43144 ] =  0x9c17581b
# updma_buf_s2m[ 43145 ] =  0xe60690ff
# updma_buf_s2m[ 43146 ] =  0x484fda00
# updma_buf_s2m[ 43147 ] =  0xb4670999
# updma_buf_s2m[ 43148 ] =  0xedf6b617
# updma_buf_s2m[ 43149 ] =  0x4008546b
# updma_buf_s2m[ 43150 ] =  0xb2ed28a8
# updma_buf_s2m[ 43151 ] =  0xeee1b0b7
# updma_buf_s2m[ 43152 ] =  0x68da58d6
# updma_buf_s2m[ 43153 ] =  0x8138e6c5
# updma_buf_s2m[ 43154 ] =  0xe16e0eca
# updma_buf_s2m[ 43155 ] =  0x3139e1e2
# updma_buf_s2m[ 43156 ] =  0xad6532f4
# updma_buf_s2m[ 43157 ] =  0xed23cef7
# updma_buf_s2m[ 43158 ] =  0x443a08e6
# updma_buf_s2m[ 43159 ] =  0x97a94a94
# updma_buf_s2m[ 43160 ] =  0xe787c2a0
# updma_buf_s2m[ 43161 ] =  0x52cd09d8
# updma_buf_s2m[ 43162 ] =  0x1acc94d7
# updma_buf_s2m[ 43163 ] =  0x80866a1
# updma_buf_s2m[ 43164 ] =  0x4a58f0c2
# updma_buf_s2m[ 43165 ] =  0xebcb2189
# updma_buf_s2m[ 43166 ] =  0xff6d090c
# updma_buf_s2m[ 43167 ] =  0x5d786ab6
# updma_buf_s2m[ 43168 ] =  0xca1d2d8c
# updma_buf_s2m[ 43169 ] =  0xfca54aa2
# updma_buf_s2m[ 43170 ] =  0x5c0e1a40
# updma_buf_s2m[ 43171 ] =  0xbfca979a
# updma_buf_s2m[ 43172 ] =  0xfab62416
# updma_buf_s2m[ 43173 ] =  0x727a9ecf
# updma_buf_s2m[ 43174 ] =  0x9c99f5c9
# updma_buf_s2m[ 43175 ] =  0xf96dde53
# updma_buf_s2m[ 43176 ] =  0x61232376
# updma_buf_s2m[ 43177 ] =  0xa28ed044
# updma_buf_s2m[ 43178 ] =  0xf72ce3f8
# updma_buf_s2m[ 43179 ] =  0x46322181
# updma_buf_s2m[ 43180 ] =  0xb5a36bab
# updma_buf_s2m[ 43181 ] =  0xf26b2ae3
# updma_buf_s2m[ 43182 ] =  0x45824186
# updma_buf_s2m[ 43183 ] =  0xbbd4b5f2
# updma_buf_s2m[ 43184 ] =  0xec7b2762
# updma_buf_s2m[ 43185 ] =  0x66461dfb
# updma_buf_s2m[ 43186 ] =  0xa12d9b2a
# updma_buf_s2m[ 43187 ] =  0xebe76d6f
# updma_buf_s2m[ 43188 ] =  0x564e3cc5
# updma_buf_s2m[ 43189 ] =  0xe36e0ceb
# updma_buf_s2m[ 43190 ] =  0xfb948a56
# updma_buf_s2m[ 43191 ] =  0x76720759
# updma_buf_s2m[ 43192 ] =  0xc170c257
# updma_buf_s2m[ 43193 ] =  0x13838ff
# updma_buf_s2m[ 43194 ] =  0x51b95000
# updma_buf_s2m[ 43195 ] =  0xbfbd9775
# updma_buf_s2m[ 43196 ] =  0x6b2a8bc
# updma_buf_s2m[ 43197 ] =  0x42937943
# updma_buf_s2m[ 43198 ] =  0xcb9541cf
# updma_buf_s2m[ 43199 ] =  0xff9fd926
# updma_buf_s2m[ 43200 ] =  0x52f98002
# updma_buf_s2m[ 43201 ] =  0xb34e5d7c
# updma_buf_s2m[ 43202 ] =  0xfd73f3bc
# updma_buf_s2m[ 43203 ] =  0x4a3f5f3a
# updma_buf_s2m[ 43204 ] =  0xaecc38e3
# updma_buf_s2m[ 43205 ] =  0x940564a
# updma_buf_s2m[ 43206 ] =  0x4a7b1244
# updma_buf_s2m[ 43207 ] =  0xa62d1e8c
# updma_buf_s2m[ 43208 ] =  0x60fb53a
# updma_buf_s2m[ 43209 ] =  0x60cc4d16
# updma_buf_s2m[ 43210 ] =  0x87e2cf66
# updma_buf_s2m[ 43211 ] =  0x895c05b
# updma_buf_s2m[ 43212 ] =  0x5f30daf8
# updma_buf_s2m[ 43213 ] =  0x923fa07e
# updma_buf_s2m[ 43214 ] =  0x71c238a
# updma_buf_s2m[ 43215 ] =  0x4f237ea4
# updma_buf_s2m[ 43216 ] =  0xa8138d3d
# updma_buf_s2m[ 43217 ] =  0x380e45c
# updma_buf_s2m[ 43218 ] =  0x7392cb64
# updma_buf_s2m[ 43219 ] =  0x837665b0
# updma_buf_s2m[ 43220 ] =  0x3354caa
# updma_buf_s2m[ 43221 ] =  0x674d03b0
# updma_buf_s2m[ 43222 ] =  0x89aba4f6
# updma_buf_s2m[ 43223 ] =  0xff44f1de
# updma_buf_s2m[ 43224 ] =  0x40704406
# updma_buf_s2m[ 43225 ] =  0xcae5283b
# updma_buf_s2m[ 43226 ] =  0xf55ecfd6
# updma_buf_s2m[ 43227 ] =  0x61045729
# updma_buf_s2m[ 43228 ] =  0xfe75a761
# updma_buf_s2m[ 43229 ] =  0xd6b3f8fd
# updma_buf_s2m[ 43230 ] =  0x5b526dbe
# updma_buf_s2m[ 43231 ] =  0xe8003ab1
# updma_buf_s2m[ 43232 ] =  0xd8dba7ca
# updma_buf_s2m[ 43233 ] =  0x761f9728
# updma_buf_s2m[ 43234 ] =  0xc2133a0c
# updma_buf_s2m[ 43235 ] =  0xc6fe9d91
# updma_buf_s2m[ 43236 ] =  0x47b11e22
# updma_buf_s2m[ 43237 ] =  0xcdb687b5
# updma_buf_s2m[ 43238 ] =  0xd136e135
# updma_buf_s2m[ 43239 ] =  0x5e0a0382
# updma_buf_s2m[ 43240 ] =  0xaaa32684
# updma_buf_s2m[ 43241 ] =  0xae0ea73a
# updma_buf_s2m[ 43242 ] =  0x6114db86
# updma_buf_s2m[ 43243 ] =  0x950b0017
# updma_buf_s2m[ 43244 ] =  0xa59db162
# updma_buf_s2m[ 43245 ] =  0x3f373f74
# updma_buf_s2m[ 43246 ] =  0xbc3fae9f
# updma_buf_s2m[ 43247 ] =  0xd8bbd4f2
# updma_buf_s2m[ 43248 ] =  0x45343a03
# updma_buf_s2m[ 43249 ] =  0xd8a53634
# updma_buf_s2m[ 43250 ] =  0x14b56a01
# updma_buf_s2m[ 43251 ] =  0x6660d3c2
# updma_buf_s2m[ 43252 ] =  0xa0cd1d07
# updma_buf_s2m[ 43253 ] =  0xa07eb6c
# updma_buf_s2m[ 43254 ] =  0x39e15441
# updma_buf_s2m[ 43255 ] =  0xaaabc6a8
# updma_buf_s2m[ 43256 ] =  0xf6e6a86a
# updma_buf_s2m[ 43257 ] =  0x6f778b76
# updma_buf_s2m[ 43258 ] =  0xc9074852
# updma_buf_s2m[ 43259 ] =  0x848721a
# updma_buf_s2m[ 43260 ] =  0x4c4ac3c6
# updma_buf_s2m[ 43261 ] =  0xf7d5d273
# updma_buf_s2m[ 43262 ] =  0xff87a79e
# updma_buf_s2m[ 43263 ] =  0x4ca663ae
# updma_buf_s2m[ 43264 ] =  0x2520c1f7
# updma_buf_s2m[ 43265 ] =  0xfd922b5d
# updma_buf_s2m[ 43266 ] =  0x7087058f
# updma_buf_s2m[ 43267 ] =  0xf0ff011d
# updma_buf_s2m[ 43268 ] =  0xf5008ead
# updma_buf_s2m[ 43269 ] =  0x792dd405
# updma_buf_s2m[ 43270 ] =  0xd0fa7e3c
# updma_buf_s2m[ 43271 ] =  0xeda96865
# updma_buf_s2m[ 43272 ] =  0x5306772c
# updma_buf_s2m[ 43273 ] =  0xed4ef81e
# updma_buf_s2m[ 43274 ] =  0xe4d06cab
# updma_buf_s2m[ 43275 ] =  0x58941e13
# updma_buf_s2m[ 43276 ] =  0xe6941fab
# updma_buf_s2m[ 43277 ] =  0xdbf3d14b
# updma_buf_s2m[ 43278 ] =  0x7f591810
# updma_buf_s2m[ 43279 ] =  0xe1b27006
# updma_buf_s2m[ 43280 ] =  0xd9a04d60
# updma_buf_s2m[ 43281 ] =  0x7ae92d7f
# updma_buf_s2m[ 43282 ] =  0x10794d0f
# updma_buf_s2m[ 43283 ] =  0xb0b37745
# updma_buf_s2m[ 43284 ] =  0x7c51f694
# updma_buf_s2m[ 43285 ] =  0xf472a454
# updma_buf_s2m[ 43286 ] =  0xab1329ed
# updma_buf_s2m[ 43287 ] =  0x59fbe13d
# updma_buf_s2m[ 43288 ] =  0x2cb10c01
# updma_buf_s2m[ 43289 ] =  0xcc471626
# updma_buf_s2m[ 43290 ] =  0x6c6c6028
# updma_buf_s2m[ 43291 ] =  0xbc05b51a
# updma_buf_s2m[ 43292 ] =  0x1cbdfac5
# updma_buf_s2m[ 43293 ] =  0x6db0a6ee
# updma_buf_s2m[ 43294 ] =  0xdad213d1
# updma_buf_s2m[ 43295 ] =  0xe2d52588
# updma_buf_s2m[ 43296 ] =  0x7b34c92e
# updma_buf_s2m[ 43297 ] =  0xc173d499
# updma_buf_s2m[ 43298 ] =  0xe5365d02
# updma_buf_s2m[ 43299 ] =  0x7dd6a93a
# updma_buf_s2m[ 43300 ] =  0xd887c2f7
# updma_buf_s2m[ 43301 ] =  0xb1e65608
# updma_buf_s2m[ 43302 ] =  0x476fc099
# updma_buf_s2m[ 43303 ] =  0xe0f4bc4a
# updma_buf_s2m[ 43304 ] =  0xd64d799c
# updma_buf_s2m[ 43305 ] =  0x3bb3a7fc
# updma_buf_s2m[ 43306 ] =  0xb878dddb
# updma_buf_s2m[ 43307 ] =  0xe28030dc
# updma_buf_s2m[ 43308 ] =  0x57a83679
# updma_buf_s2m[ 43309 ] =  0xd3b7c189
# updma_buf_s2m[ 43310 ] =  0xe24f7ab5
# updma_buf_s2m[ 43311 ] =  0x4cf9744d
# updma_buf_s2m[ 43312 ] =  0xe8097a6f
# updma_buf_s2m[ 43313 ] =  0xf6612336
# updma_buf_s2m[ 43314 ] =  0x477507a2
# updma_buf_s2m[ 43315 ] =  0xc115cd78
# updma_buf_s2m[ 43316 ] =  0xdb995c6e
# updma_buf_s2m[ 43317 ] =  0x429a19f8
# updma_buf_s2m[ 43318 ] =
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-ed30bbcc4c03> in <module>
#       1 # print out updma_buf_s2m
#       2 for i in range(test_length*3):
# ----> 3     print("updma_buf_s2m[", i, "] = ", hex(updma_buf_s2m[i]))
#
# /usr/local/share/pynq-venv/lib/python3.8/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/share/pynq-venv/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/share/pynq-venv/lib/python3.8/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/share/pynq-venv/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
